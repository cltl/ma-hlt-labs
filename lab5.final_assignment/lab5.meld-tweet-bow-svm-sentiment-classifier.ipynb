# %% [markdown]
# # Lab5 Creating a BoW SVM Sentiment Classifier from MELD and Tweets

# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# To classify your conversation with Eliza, you need to build a SVM emotion classifier using a TFIFD Bag-of-Word representation using all the data from MELD and WASSA Tweets. In this case you can use al the train, test and development data to train the final classifier as you are going to test it on your conversation. In this notebooke, we convert the Ekman annotations to sentiment values.

# %%
import pandas as pd
from collections import Counter
import nltk
from nltk.corpus import stopwords
import pickle
import sklearn
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import seaborn as sns

# %%
# MAP EKMAN TO SENTIMENT
sentiment_map={}

# HERE COMES THE CODE TO MAP THE EKMAN TEST LABELS TO SENTIMENT TEST LABEL

def ekman_to_sentiment (sentiment_map, test_labels):
    human_sentiment_test_labels = []
    return human_sentiment_test_labels

# %% [markdown]
# ### 1. Loading the tweet data set

# %%
# HERE COMES THE CODE TO LOAD THE TWEET TRAINING DATA
# dftweets_train =

# %%
# HERE COMES THE CODE TO LOAD THE TWEET TEST DATA
# dftweets_test =

# %%
# HERE COMES THE CODE TO LOAD THE TWEET DEVELOPMENT DATA
# dftweets_dev =

# %% [markdown]
# Get the training texts and labels

# %%
tweet_train_instances = []
# HERE COMES THE CODE TO GET THE TEXT FROM TRAIN

tweet_train_labels = []
# HERE COMES THE CODE TO GET THE LABELS FROM TRAIN

tweet_test_instances = []
# HERE COMES THE CODE TO GET THE TEXT FROM TEST

tweet_test_labels = []
# HERE COMES THE CODE TO GET THE LABEL FROM TEST
    
tweet_dev_instances = []
# HERE COMES THE CODE TO GET THE TEXT FROM DEV

tweet_dev_labels = []
# HERE COMES THE CODE TO GET THE LABELS FROM DEV

# %% [markdown]
# ## 2. Loading the MELD data set

# %%
# HERE COMES THE CODE TO LOAD THE MELD TRAINING DATA
# dfmeld_train

# %%
# HERE COMES THE CODE TO LOAD THE MELD TEST DATA
# dfmeld_tEST

# %%
# HERE COMES THE CODE TO LOAD THE MELD DEVELOPMENT DATA
# dfmeld_DEV

# %%
meld_train_instances = []
# HERE COMES THE CODE TO GET THE TEXT FROM TRAIN

meld_train_labels = []
# HERE COMES THE CODE TO GET THE LABELS FROM TRAIN

meld_test_instances = []
# HERE COMES THE CODE TO GET THE TEXT FROM TEST

meld_test_labels = []
# HERE COMES THE CODE TO GET THE LABEL FROM TEST
    
meld_dev_instances = []
# HERE COMES THE CODE TO GET THE TEXT FROM DEV

meld_dev_labels = []
# HERE COMES THE CODE TO GET THE LABELS FROM DEV

# %% [markdown]
# ## 3. Combining the training data

# %%
# HERE COMES THE CODE FOR CREATING A SINGLE TRAINING DATA SET AND CONVERT THE EKMAN LABELS TO SENTIMENT
# TWEET TRAIN, TEST and DEV INSTANCES
# MELD TRAIN, TEST and DEV INSTANCES

# TWEET TRAIN, TEST and DEV LABEL
# MELD TRAIN, TEST and DEV LABEL


combined_train_instances = []
combined_train_ekman_labels = []

combined_train_labels = ekman_to_sentiment(sentiment_map, combined_train_ekman_labels)

# %%
# HERE COMES THE CODE TO CHECK THE DATA AND ANALYSE THE DISTRIBUTION OVER THE SENTIMENT LABELS

# %%
# HERE COMES THE CODE TO TRAIN AN SVM CLASSIFIER WITH A BOW TFIDF DATA REPRESENTATION

# %% [markdown]
# ## 4. Saving the final combined classifier to disk

# %%
# HERE COMES THE CODE TO SAVE THE CLASSIFIER TO DISK SO THAT YOU CAN USE IT FOR THE FINAL ASSIGNMENT

# %% [markdown]
# # End of notebook
