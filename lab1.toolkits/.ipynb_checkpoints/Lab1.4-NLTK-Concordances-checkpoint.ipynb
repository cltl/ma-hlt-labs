# %% [markdown]
# # Lab1.4: Using the Natural Language Toolkit (NLTK) to create concordances for polysemous words

# %% [markdown]
# Concordancers are powerful tools that show patterns and structures in languages centered around words. In this lab session, you learn how to create a concordance or Key Word In Context (KWIC).
#
# The goals of this assignment are:
#
# * learn how different meanings of words are reflected by their contexts
# * learn how to process text files with the NLTK toolkit
# * learn how to build a concordance or KWIC (Key Word In Context) index using NLTK

# %% [markdown]
# ##  Natural Language Toolkit (NLTK)

# %% [markdown]
# For this assignment you will use the NLTK (Natural Language Tool Kit) package. NLTK is a powerfull python package that provides easy access to popular corpora and lexical resources. Also, it contains a wide range of text processing modules (hence the name toolkit). NLTK is perfect for getting started with Natural Language Processing since it allows you to study each NLP task separately, which means that you can analyze the input, the algorithm, and the output. NLTK is an open source and community-driven project. You can find both the package and the book, which is a guided tutorial how to use the package, here:
#
# http://www.nltk.org
#
# On the main page, you find instructions on how to install NLTK on your local machine. Note that you do not need to install Python as it is already installed through Anaconda.

# %% [markdown]
# To install NLTK you need to open a terminal to carry out a command.
#
# MAC/Unix
# pip install --user -U nltk
#
# Windows
# pip install nltk

# %% [markdown]
# Note that you only need to install NLTK once. The next time you launch a notebook or Python script in which you want to use NLTK it is already installed and you can immedialtely go to the next step to import it.

# %% [markdown]
# If you installed NLTK succesfully, you can import the module into you notebook as follows:

# %%
import nltk

# %% [markdown]
# Importing is as if your opened the toolkit and now you can use any of the tools provided. There is a lot of machinery and the NLTK online book explain step by step how to use it. You can get an idea by doing the following in your notebook. Type "nltk." and press the TAB key. You will see a pop-up window with a lot of functions.
# The next image shows how this look like. Try it your self and scroll down the list.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename = "img/nltk.tools.png", width=400, height=400)

# %%
The NLTK tools need data

# %%
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/piek/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /Users/piek/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/piek/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/piek/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/piek/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/piek/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# ...

# %% [markdown]
# NLTK needs this data to be able to perform certain functions and for this assignment to apply tokenization. Next time you start this notebook, you do not need to download this again once the directory is created. Note that you do need to do the “import nltk” every time you start  the python environment.

# %% [markdown]
# Now your computer is stuffed with a lot of interesting language material!
# Where is this stuff on your computer?
#
# Depending on your OS the language stuff is stored in a new folder called "nltk_data" somehwere in the home folder of your user account. Using my_name as an example of a username, this can be one of the following:
#
# * Mac OS: "/Users/my_name/nltk_data"
# * Windows 10: "C:\Users\my_name'nltk_data"
# * Linux: "/home/my_name/nltk_data"

# %%
# I am using a mac and I can use the ls command to get a listing through JupyterLab.
# Try to do the same for your own computer and adapt the path according to your OS and your username
ls /Users/piek/nltk_data #replace "/Users/piek/" to your the path on your own computer
# Out:
# chunkers/   grammars/   misc/       sentiment/  taggers/
# corpora/    help/       models/     stemmers/   tokenizers/

# %% [markdown]
# You see that NLTK contains tools such as chunkers, taggers, stemmers, tokenizers but also data such as corpora. It is very useful to look into these folders and check what is there to familiarize yourself with it.

# %%
ls /Users/piek/nltk_data/corpora #replace "/Users/piek/" to your the path on your own computer
# Out:
# abc/                         panlex_swadesh.zip
# abc.zip                      paradigms/
# alpino/                      paradigms.zip
# alpino.zip                   pil/
# biocreative_ppi/             pil.zip
# biocreative_ppi.zip          pl196x/
# brown/                       pl196x.zip
# brown.zip                    ppattach/
# brown_tei/                   ppattach.zip
# brown_tei.zip                problem_reports/
# cess_cat/                    problem_reports.zip
# cess_cat.zip                 product_reviews_1/
# cess_esp/                    product_reviews_1.zip
# cess_esp.zip                 product_reviews_2/
# chat80/                      product_reviews_2.zip
# chat80.zip                   propbank.zip
# city_database/               pros_cons/
# city_database.zip            pros_cons.zip
# cmudict/                     ptb/
# cmudict.zip                  ptb.zip
# comparative_sentences/       qc/
# comparative_sentences.zip    qc.zip
# ...

# %% [markdown]
# Now you are ready to use all the tools in the toolkit and do fancy stuff with language. You find everything described and explained in the book and you should start with the instructions given in: http://www.nltk.org/book/ch01.html. You can go on forever if you like (and it is fun to do) but you need to do the assignment so lets stop when you reach section 1.4.
#
# You are done playing? This is what you need to do for the assignment with the files you uploaded on the server.

# %% [markdown]
# ## Use NLTK concordancer to analyse the context of polysemous words

# %% [markdown]
# Look for 5 short texts in which a word is clearly used in one meaning and 5 short texts in which it is used in another meaning. You can choose one of the following words:
#
# bass (example used in lecture)
# mouse
# horse
# queen
# knight
# ball

# %% [markdown]
# Make sure these are text files and not HTML (Web pages), MS Word files or PDF. Professional word processing software creates binary files that cannot be read as text as such. To create such text files you need a plain text editor:
#
# * Linux: Emacs,Nano
# * Mac: BBEdit lite
# * Windows: Notepad++
#
# If you find some texts, e.g. online, you can copy/paste it to a new file in these editors. If there are any weird characters, you will see them. You can also open a terminal and check the content using the command “type <name of the file> (Windows) or “cat <name of the file> (Mac, Unix, Linux).
#
# Try to save the text as clean as possible in a searate file.

# %% [markdown]
# Store the text files in a separate directory or folder. Make sure the files have clearly recognisable names, e.g. meaning1.1, meaning1.2, …, meaning1.5 and meaning2.1, meaning2.2, …, meaning2.5 so that you know which files belong to what meaning later on.

# %% [markdown]
# ### Reading the content of a file

# %% [markdown]
# Next, we are going to use a python command to create a so-called handle to a file for reading its content. The handle is represented by the variable 'f'. The 'open' command takes one argument which is the path to the location of the file.

# %%
f=open('texts/animal_mouse1.txt')

# %% [markdown]
# Our 'f' is a python object for which a number of functions are built in. If you type in a Code cell:
#
# f.
#
# and press TAB, you will see an overview of the listed functions as shown in the next screen dump. Check if you get the same.You can scroll down the popup to see all the functions.

# %%
Image(filename = "img/f.png", width=200, height=100)

# %% [markdown]
# We are going to use the read function to get the content of the file as a string of words and assign this to a variable with the name "text".

# %%
text=f.read()

# %% [markdown]
# Now the variable "text" has the content of the file as its value. Type first "print(text)" and next "text" to obtain the value.

# %%
print(text)
# Out:
# A mouse, plural mice, is a small rodent characteristically having a
# pointed snout, small rounded ears, a body-length scaly tail and a high
# breeding rate. The best known mouse species is the common house mouse
# (Mus musculus). It is also a popular pet. In some places, certain kinds
# of field mice are locally common. They are known to invade homes for
# food and shelter.

# %%
text
# Out:
# 'A mouse, plural mice, is a small rodent characteristically having a\npointed snout, small rounded ears, a body-length scaly tail and a high\nbreeding rate. The best known mouse species is the common house mouse\n(Mus musculus). It is also a popular pet. In some places, certain kinds\nof field mice are locally common. They are known to invade homes for\nfood and shelter.'

# %% [markdown]
# See the difference between the two commands. The former shows a nice display of the text, while the latter has the text between qoutes and shows the newline feeds throuvh the so-called controll characters "\n". The last version is the true value.

# %% [markdown]
# We have more files for a single meaning of a word. Now we want to add the content of the other 4 files to the text variable. For this we need to read them one-by-one.

# %% [markdown]
# But note!!! We need to ADD the content and not assign the new content to text and thus REMOVING the old content. We will re-use the handle 'f' to access each but we add the content to text instead of assigning it.

# %% [markdown]
# **Excersise**: try to experiment using "=" and "+=" to see the difference for the values of the variable "text".

# %%
f=open('texts/animal_mouse2.txt')
text+=f.read()

# %% [markdown]
# Note the subtle difference with the first file. For adding the content to “raw” from the first file we used “=“ but for all the next files we used “+=“ instead of “=“. If you use just “=“ you replace the content that “raw” has at that point by the new content. By using “+=“ we add the content and do not overwrite the previous content. Add is what we want after the first file. We want ALL the text of a meaning1 together. Print the value of text to see if you did it right.

# %%
print(text)
# Out:
# A mouse, plural mice, is a small rodent characteristically having a
# pointed snout, small rounded ears, a body-length scaly tail and a high
# breeding rate. The best known mouse species is the common house mouse
# (Mus musculus). It is also a popular pet. In some places, certain kinds
# of field mice are locally common. They are known to invade homes for
# food and shelter.Researchers narrowing in on early neuronal functioning stages of
# development, well before Huntington’s disease symptoms appear, believe
# they have found a potentially important path to intervening with the
# diabetes medication metformin. Their research was conducted in a mouse
# model of the disease.Mouse, (genus Mus), the common name generally but imprecisely applied to
# rodents found throughout the world with bodies less than about 12 cm (5
# inches) long. In a scientific context, mouse refers to any of the 38
# species in the genus Mus, which is the Latin word for mouse. The house
# ...

# %%
f=open('texts/animal_mouse3.txt')
text+=f.read()

# %%
f=open('texts/animal_mouse4.txt')
text+=f.read()

# %%
f=open('texts/animal_mouse5.txt')
text+=f.read()

# %% [markdown]
# If you carried out the instructions correctly, the variable "text" now contains the concatenated content of all files with a single meaning of the word "mouse". Use the print(text) command to test this.

# %% [markdown]
# **Python excersise**: You have now carried out the reading as 5 separate instructions. In the Python course you will learn how to do this in a control loop so that you can do this for any number of files and with a single instruction.

# %% [markdown]
# ### Get the separate word tokens from the content

# %%
import nltk
tokens=nltk.word_tokenize(text)

# %% [markdown]
# The tokenize function takes a full text as input as a string and splits the words using spaces and punctuation. Tokenization is not trivial but essential to do anything with a text. To see what the function generates we use the following command to show the first ten tokens from the list of tokens.

# %%
tokens[:10]
# Out:
# ['A', 'mouse', ',', 'plural', 'mice', ',', 'is', 'a', 'small', 'rodent']

# %% [markdown]
# **Excersise**: Any idea how to print the first 20 items? Or the last 10? Check out the Python handbooks to find out.

# %% [markdown]
# NLTK has specific function to process and analyse a text. To use these functions it is necessary to create  a NLTK text object from a list of tokens. We do that as follows:

# %%
text_object=nltk.Text(tokens)

# %% [markdown]
# Try out "text_object." and TAB to see what functions are available. Use the NLTK book to learn more: http://www.nltk.org/book/ch01.html.
#
# * text_object.collocations()
# * lexicon=text_object.vocab()
# * lexicon.keys()
# * lexicon.items()
#
# One of these function is the concordance function, which is what we are going to use next.

# %% [markdown]
# ### Call the NLTK concordance function

# %% [markdown]
# The concordance function takes a word as input to create the concordance surrounding this word based on the text. We are going to use the word 'mouse'

# %%
text_object.concordance('mouse')
# Out:
# Displaying 10 of 10 matches:
#  mouse , plural mice , is a small rodent ch
#  high breeding rate . The best known mouse species is the common house mouse (
# wn mouse species is the common house mouse ( Mus musculus ) . It is also a popu
#  . Their research was conducted in a mouse model of the disease.Mouse , ( genus
# s ) long . In a scientific context , mouse refers to any of the 38 species in t
# us Mus , which is the Latin word for mouse . The house mouse ( Mus musculus ) ,
# the Latin word for mouse . The house mouse ( Mus musculus ) , native to Central
# s ) long . In a scientific context , mouse refers to any of the 38 species in t
# us Mus , which is the Latin word for mouse . The house mouse ( Mus musculus ) ,
# the Latin word for mouse . The house mouse ( Mus musculus ) , native to Central

# %% [markdown]
# As shown in the instructions of http://www.nltk.org/book/ch01.html the concordance function shows the lines from the text in which the target word occures with the left and right context. By centralizing the text around the target word a nice overview is obtained of the contexts.

# %% [markdown]
# ## Concordance for computer mouse

# %%
f=open('texts/comp_mouse1.txt')

# %%
text_comp=f.read()

# %%
f=open('texts/comp_mouse2.txt')
text_comp+=f.read()

# %%
f=open('texts/comp_mouse3.txt')
text_comp+=f.read()

# %%
f=open('texts/comp_mouse4.txt')
text_comp+=f.read()

# %%
f=open('texts/comp_mouse5.txt')
text_comp+=f.read()

# %%
print(text_comp)
# Out:
# A computer mouse is a hand-held pointing device that detects
# two-dimensional motion relative to a surface. This motion is typically
# translated into the motion of a pointer on a display, which allows a
# smooth control of the graphical user interface. The first public
# demonstration of a mouse controlling a computer system was in 1968.
# Originally wired to a computer, many modern mice are cordless, relying
# on short-range radio communication with the connected system. Mice
# originally used a ball rolling on a surface to detect motion, but modern
# mice often have optical sensors that have no moving parts. In addition
# to moving a cursor, computer mice have one or more buttons to allow
# operations such as selection of a menu item on a display. Mice often
# also feature other elements, such as touch surfaces and "wheels", which
# enable additional control and dimensional input.A computer mouse is a handheld hardware input device that controls a
# ...

# %%
tokens=nltk.word_tokenize(text_comp)

# %%
text_object=nltk.Text(tokens)

# %%
text_object.concordance('mouse')
# Out:
# Displaying 15 of 15 matches:
#  mouse is a hand-held pointing device that
#  The first public demonstration of a mouse controlling a computer system was in
# rol and dimensional input.A computer mouse is a handheld hardware input device
# olders . For desktop computers , the mouse is placed on a flat surface such as
# s placed on a flat surface such as a mouse pad or a desk and is placed in front
#  is an example of a desktop computer mouse with two buttons and a wheel.Some ta
#  manufacturers may say that the best mouse is a finger tap , but we just don ’
# There ’ s nothing quite like using a mouse to navigate your PC . No matter whet
# nruly as you prefer.With Apple Magic Mouse 2 Space Gray you swipe through web p
# multi-touch surface you control this mouse just like your smartphone . Those wh
# e precision of a laser . Apple Magic Mouse 2 works smoothly on any surface . An
#  rechargeable battery and you have a mouse that you can benefit from for years.
# ...
