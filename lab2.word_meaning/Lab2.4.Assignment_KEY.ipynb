# %% [markdown]
# # Lab2: Assignment - the lexicon of emotionally loaded words

# %% [markdown]
# Emotions are difficult to grasp and our language to express emotions is subtle and nuanced. What are the words that we can use to express emotions?
#
# In this assignment, you need to find emotion expressing words through Wordnet-NLTK and through Word embeddings.
#
# We start from the six basic emotions that Ekman and his team claimed to hold universally across the facial expressions of people from many different cultures:
#
# <img src="images/ekman-faces.png" width="500" height="600">
#
# The emotions are: anger, disgust, fear, joy, sadness and surprise. Many emotion detection modules in NLP use these six emotions.
#
# Refeernce: Ekman, Paul, Wallace V. Friesen, Maureen O'sullivan, Anthony Chan, Irene Diacoyanni-Tarlatzis, Karl Heider, Rainer Krause et al. "Universals and cultural differences in the judgments of facial expressions of emotion." Journal of personality and social psychology 53, no. 4 (1987): 712

# %% [markdown]
# ## 1. Finding emotional words in WordNet

# %% [markdown]
# When you ask ChatGPT how to extract emotion words from WordNet-NLTK, it will give you more or less the following answer and code:

# %% [markdown]
# ### Text generated by ChatGPT
# To get **all words related to basic emotion terms** (like *sadness, anger, disgust, surprise, fear, joy*) using **WordNet (NLTK)**, you can:
#
# 1. Loop over each basic emotion term.
# 2. Query **adjective, noun, and verb synsets** (since emotions can span multiple parts of speech).
# 3. Collect **related words**:
#
#    * Synonyms (`lemmas`)
#    * Antonyms (`lemma.antonyms()`)
#    * Similar adjectives (`similar_tos()` for adjectives)
#    * Derivationally related forms
#    * Hypernyms, hyponyms, meronyms, etc. (for nouns and verbs)
#
# ---

# %%
### Code generated by ChatGPT
### ✅ General Code to Expand Emotion Terms

from nltk.corpus import wordnet as wn

def expand_emotion_word(word):
    related_words = set()
    
    # Check all parts of speech
    for pos in [wn.NOUN, wn.ADJ, wn.VERB]:
        synsets = wn.synsets(word, pos=pos)
        for syn in synsets:
            # Synonyms
            for lemma in syn.lemmas():
                related_words.add(lemma.name())

                # Antonyms
                for antonym in lemma.antonyms():
                    related_words.add(antonym.name())

                # Derivationally related forms
                for deriv in lemma.derivationally_related_forms():
                    related_words.add(deriv.name())

            # Adjective similarity
            if pos == wn.ADJ:
                for similar in syn.similar_tos():
                    for lemma in similar.lemmas():
                        related_words.add(lemma.name())

            # Hypernyms, hyponyms, meronyms, holonyms
            for related_syn in syn.hypernyms() + syn.hyponyms() + syn.part_meronyms() + syn.member_holonyms():
                for lemma in related_syn.lemmas():
                    related_words.add(lemma.name())

    return sorted(related_words)

# %%
### Code generated by ChatGPT

basic_emotions = ['sadness', 'anger', 'disgust', 'surprise', 'fear', 'joy']

wordnet_emotion_expansions = {}

for emotion in basic_emotions:
    words = expand_emotion_word(emotion)
    wordnet_emotion_expansions[emotion] = words

for emotion, words in wordnet_emotion_expansions.items():
    print(f"{emotion.upper()}:{len(words)}")
    print(words)
    print()
# Out:
# SADNESS:37
# ['bereavement', 'cheerlessness', 'dejectedness', 'depression', 'desolation', 'dispiritedness', 'dolefulness', 'downheartedness', 'feeling', 'forlornness', 'gloominess', 'gloomy', 'happiness', 'heaviness', 'loneliness', 'low-spiritedness', 'lowness', 'lugubrious', 'lugubriousness', 'melancholy', 'misery', 'mourning', 'poignance', 'poignancy', 'regret', 'rue', 'ruefulness', 'sad', 'sadness', 'sorrow', 'sorrowful', 'sorrowfulness', 'tearfulness', 'uncheerfulness', 'unhappiness', 'unhappy', 'weepiness']
#
# ANGER:57
# ['aggravate', 'anger', 'angriness', 'angry', 'annoyance', 'arouse', 'bad_temper', 'bridle', 'chafe', 'choler', 'choleric', 'combust', 'dander', 'deadly_sin', 'elicit', 'emotion', 'emotional_arousal', 'enkindle', 'enrage', 'enragement', 'evoke', 'exacerbate', 'exasperate', 'experience', 'feel', 'fire', 'fury', 'gall', 'hackles', 'huffiness', 'ill_temper', 'incense', 'indignation', 'infuriate', 'infuriation', 'ira', 'ire', 'irk', 'kindle', 'madden', 'madness', 'miff', 'mortal_sin', 'offence', 'offend', 'offense', 'outrage', 'pique', 'provoke', 'rage', 'raise', 'raise_the_roof', 'see_red', 'steam', 'umbrage', 'vexation', 'wrath']
#
# DISGUST:34
# ['abhorrence', 'abomination', 'appal', 'appall', 'churn_up', 'detestation', 'disgust', 'dislike', 'excite', 'execration', 'gross_out', 'horror', 'loathing', 'nausea', 'nauseate', 'odium', 'offend', 'outrage', 'repel', 'repellant', 'repellent', 'repugnance', 'repulse', 'repulsion', 'repulsive', 'revolt', 'revulsion', 'scandalise', 'scandalize', 'shock', 'sicken', 'stimulate', 'stir', "turn_one's_stomach"]
#
# SURPRISE:42
# ['act', 'affect', 'alteration', 'amaze', 'amazement', 'assail', 'astonish', 'astonishment', 'astound', 'attack', 'ball_over', 'blindside', 'blow', 'blow_out_of_the_water', 'boggle', 'bombshell', 'bowl_over', 'catch', 'change', 'coup_de_theatre', 'disruption', 'explode_a_bombshell', 'eye_opener', 'flabbergast', 'floor', 'impress', 'modification', 'move', 'peripeteia', 'peripetia', 'peripety', 'perturbation', 'shock', 'storm', 'strike', 'stunner', 'surprisal', 'surprise', 'surpriser', 'take_aback', 'thunderbolt', 'thunderclap']
#
# FEAR:54
# ['affright', 'alarm', 'anxiety', 'apprehension', 'apprehensiveness', 'awe', 'care', 'chill', 'cold_sweat', 'concern', 'consternation', 'creeps', 'dismay', 'dread', 'emotion', 'enshrine', 'esteem', 'fear', 'fearful', 'fearfulness', 'fearlessness', 'fright', 'frisson', 'horror', 'hysteria', 'intimidation', 'panic', 'panic_attack', 'prise', 'prize', 'quiver', 'regret', 'respect', 'revere', 'reverence', 'reverent', 'reverential', 'saint', 'scare', 'shiver', 'shudder', 'stage_fright', 'terror', 'thrill', 'timidity', 'timidness', 'timorousness', 'tingle', 'value', 'venerate', 'veneration', 'venerator', 'worry', 'worship']
#
# JOY:35
# ['be_on_cloud_nine', 'cheer', 'cheer_up', 'chirk_up', 'delight', 'elation', 'emotion', 'excitement', 'exhilaration', 'experience', 'exuberance', 'exult', 'exultation', 'feel', 'gladden', 'high_spirits', 'joy', 'joyful', 'joyfulness', 'joyous', 'joyousness', 'jubilance', 'jubilancy', 'jubilation', 'jump_for_joy', 'lightness', 'overjoy', 'please', 'pleasure', 'positive_stimulus', 'rejoice', 'rejoicing', 'sadden', 'sorrow', 'walk_on_air']

# %% [markdown]
# ## ASSIGNMENT:

# %% [markdown]
# The basic emotion terms are all nouns, except for ```surprise``` which can also be a verb. This may have an impact on the expansion because the ```nets``` for each Part-of-Speech are poorly connected.
# Answer the following questions:
#
# 1. Create another list called ```adjectival_basic_emotions``` that contains six adjectives that correspond with the six nouns.
# 2. Extend the dictionary ```wordnet_emotion_expansions``` with six adjectival expansions.
# 4. Which words in these pairs are inconsistent with the emotion or do not imply this emotion?
# 5. Which of the Wordnet relations cause these inconsistencies in your opinion? How could you make the function more consistent?
# 3. For each pair of noun-adjective, how much overlap is there and is the overlap more consistent?
#
# TIPS:
#
# - list the nouns and adjectives in the same order and pair the list using the ```zip``` function, e.g. ```for noun, adjective in zip(basic_emotions, adjectives_basic_emotions):```
# - to get the overlap of two lists `a` and `b`, you can use the following expression: ```overlap = list(set(a)&set(b))```, which first turns the lis in a set and applies the ```&``` operator.

# %% [markdown]
# ## [YOUR CODE AND DISCUSSION GO HERE]

# %% [markdown]
# ## KEY:

# %%
#### Expanded to cover ADJECTIVES emotions
basic_emotions = ['sadness', 'anger', 'disgust', 'surprise', 'fear', 'joy']
adjectival_basic_emotions = ['sad', 'angry', 'disgusting', 'surprising', 'scary' ,'happy']

for emotion in adjectival_basic_emotions:
    words = expand_emotion_word(emotion)
    wordnet_emotion_expansions[emotion] = words

for noun, adjective in zip(basic_emotions, adjectival_basic_emotions):
    nouns = wordnet_emotion_expansions[noun]
    adjectives = wordnet_emotion_expansions[adjective]
    print(f"{noun.upper()}:{len(nouns)}:{nouns}")
    print(f"{adjective.upper()}:{len(adjectives)}: {adjectives}")
    overlap =list(set(nouns) & set(adjectives))
    print(f"Overlap: {len(overlap)}: {overlap}")
    print()
# Out:
# SADNESS:37:['bereavement', 'cheerlessness', 'dejectedness', 'depression', 'desolation', 'dispiritedness', 'dolefulness', 'downheartedness', 'feeling', 'forlornness', 'gloominess', 'gloomy', 'happiness', 'heaviness', 'loneliness', 'low-spiritedness', 'lowness', 'lugubrious', 'lugubriousness', 'melancholy', 'misery', 'mourning', 'poignance', 'poignancy', 'regret', 'rue', 'ruefulness', 'sad', 'sadness', 'sorrow', 'sorrowful', 'sorrowfulness', 'tearfulness', 'uncheerfulness', 'unhappiness', 'unhappy', 'weepiness']
# SAD:24: ['bad', 'bittersweet', 'deplorable', 'distressing', 'doleful', 'glad', 'heavyhearted', 'lament', 'lamentable', 'melancholic', 'melancholy', 'mournful', 'pensive', 'pitiful', 'sad', 'sadness', 'sorriness', 'sorrowful', 'sorry', 'tragic', 'tragical', 'tragicomic', 'tragicomical', 'wistful']
# Overlap: 4: ['melancholy', 'sorrowful', 'sadness', 'sad']
#
# ANGER:57:['aggravate', 'anger', 'angriness', 'angry', 'annoyance', 'arouse', 'bad_temper', 'bridle', 'chafe', 'choler', 'choleric', 'combust', 'dander', 'deadly_sin', 'elicit', 'emotion', 'emotional_arousal', 'enkindle', 'enrage', 'enragement', 'evoke', 'exacerbate', 'exasperate', 'experience', 'feel', 'fire', 'fury', 'gall', 'hackles', 'huffiness', 'ill_temper', 'incense', 'indignation', 'infuriate', 'infuriation', 'ira', 'ire', 'irk', 'kindle', 'madden', 'madness', 'miff', 'mortal_sin', 'offence', 'offend', 'offense', 'outrage', 'pique', 'provoke', 'rage', 'raise', 'raise_the_roof', 'see_red', 'steam', 'umbrage', 'vexation', 'wrath']
# ANGRY:40: ['aggravated', 'anger', 'angered', 'angriness', 'angry', 'black', 'choleric', 'enraged', 'furious', 'furiousness', 'fury', 'hot_under_the_collar', 'huffy', 'incensed', 'indignant', 'infuriated', 'irascible', 'irate', 'ireful', 'livid', 'mad', 'maddened', 'outraged', 'provoked', 'raging', 'smoldering', 'smouldering', 'sore', 'stormy', 'tempest', 'tempestuous', 'tempestuousness', 'umbrageous', 'unangry', 'unhealthy', 'wild', 'wildness', 'wrathful', 'wroth', 'wrothful']
# Overlap: 5: ['anger', 'fury', 'choleric', 'angriness', 'angry']
#
# DISGUST:34:['abhorrence', 'abomination', 'appal', 'appall', 'churn_up', 'detestation', 'disgust', 'dislike', 'excite', 'execration', 'gross_out', 'horror', 'loathing', 'nausea', 'nauseate', 'odium', 'offend', 'outrage', 'repel', 'repellant', 'repellent', 'repugnance', 'repulse', 'repulsion', 'repulsive', 'revolt', 'revulsion', 'scandalise', 'scandalize', 'shock', 'sicken', 'stimulate', 'stir', "turn_one's_stomach"]
# DISGUSTING:40: ['appal', 'appall', 'churn_up', 'disgust', 'disgustful', 'disgusting', 'disgustingness', 'distasteful', 'distastefulness', 'excite', 'foul', 'gross_out', 'loathly', 'loathsome', 'loathsomeness', 'nausea', 'nauseate', 'offend', 'offensive', 'outrage', 'repel', 'repellant', 'repellent', 'repelling', 'repulse', 'repulsive', 'revolt', 'revolting', 'scandalise', 'scandalize', 'shock', 'sicken', 'skank', 'skanky', 'stimulate', 'stir', "turn_one's_stomach", 'wicked', 'wickedness', 'yucky']
# Overlap: 23: ["turn_one's_stomach", 'appal', 'shock', 'nausea', 'stimulate', 'churn_up', 'repel', 'scandalise', 'disgust', 'nauseate', 'scandalize', 'outrage', 'offend', 'repellent', 'stir', 'repulsive', 'repellant', 'appall', 'repulse', 'gross_out', 'revolt', 'sicken', 'excite']
#
# SURPRISE:42:['act', 'affect', 'alteration', 'amaze', 'amazement', 'assail', 'astonish', 'astonishment', 'astound', 'attack', 'ball_over', 'blindside', 'blow', 'blow_out_of_the_water', 'boggle', 'bombshell', 'bowl_over', 'catch', 'change', 'coup_de_theatre', 'disruption', 'explode_a_bombshell', 'eye_opener', 'flabbergast', 'floor', 'impress', 'modification', 'move', 'peripeteia', 'peripetia', 'peripety', 'perturbation', 'shock', 'storm', 'strike', 'stunner', 'surprisal', 'surprise', 'surpriser', 'take_aback', 'thunderbolt', 'thunderclap']
# SURPRISING:32: ['act', 'affect', 'amaze', 'amazing', 'assail', 'astonish', 'astonishing', 'astound', 'attack', 'ball_over', 'blindside', 'blow_out_of_the_water', 'boggle', 'bowl_over', 'catch', 'explode_a_bombshell', 'flabbergast', 'floor', 'impress', 'move', 'shock', 'startling', 'storm', 'strike', 'stunning', 'surprisal', 'surprise', 'surpriser', 'surprising', 'surprisingness', 'take_aback', 'unsurprising']
# Overlap: 25: ['astound', 'shock', 'blow_out_of_the_water', 'strike', 'storm', 'surprisal', 'flabbergast', 'impress', 'floor', 'surprise', 'explode_a_bombshell', 'act', 'ball_over', 'assail', 'boggle', 'take_aback', 'catch', 'bowl_over', 'attack', 'blindside', 'affect', 'move', 'astonish', 'surpriser', 'amaze']
#
# FEAR:54:['affright', 'alarm', 'anxiety', 'apprehension', 'apprehensiveness', 'awe', 'care', 'chill', 'cold_sweat', 'concern', 'consternation', 'creeps', 'dismay', 'dread', 'emotion', 'enshrine', 'esteem', 'fear', 'fearful', 'fearfulness', 'fearlessness', 'fright', 'frisson', 'horror', 'hysteria', 'intimidation', 'panic', 'panic_attack', 'prise', 'prize', 'quiver', 'regret', 'respect', 'revere', 'reverence', 'reverent', 'reverential', 'saint', 'scare', 'shiver', 'shudder', 'stage_fright', 'terror', 'thrill', 'timidity', 'timidness', 'timorousness', 'tingle', 'value', 'venerate', 'veneration', 'venerator', 'worry', 'worship']
# SCARY:9: ['alarming', 'chilling', 'scare', 'scarey', 'scary', 'shiver', 'shivery', 'shudder', 'shuddery']
# Overlap: 3: ['shudder', 'shiver', 'scare']
#
# JOY:35:['be_on_cloud_nine', 'cheer', 'cheer_up', 'chirk_up', 'delight', 'elation', 'emotion', 'excitement', 'exhilaration', 'experience', 'exuberance', 'exult', 'exultation', 'feel', 'gladden', 'high_spirits', 'joy', 'joyful', 'joyfulness', 'joyous', 'joyousness', 'jubilance', 'jubilancy', 'jubilation', 'jump_for_joy', 'lightness', 'overjoy', 'please', 'pleasure', 'positive_stimulus', 'rejoice', 'rejoicing', 'sadden', 'sorrow', 'walk_on_air']
# HAPPY:18: ['blessed', 'blissful', 'bright', 'felicitous', 'felicitousness', 'felicity', 'fortunate', 'glad', 'golden', 'halcyon', 'happiness', 'happy', 'laughing', 'prosperous', 'riant', 'unhappy', 'well-chosen', 'willing']
# Overlap: 0: []

# %% [markdown]
# ## KEY:
#
# Inconsistencies result from "antonyms" and "hypernyms" and also "derivations". Also the function considers are the senses of a word. Restricting it to the first sense may make it more consistent.

# %% [markdown]
# ## 2. Get emotions words through word embeddings

# %% [markdown]
# ## ASSIGNMENT:

# %% [markdown]
# Wordembeddings can also be used to expand words to related words. Create two more dictionaries for emotion words derived from ```Wiki2Vec``` and ```Leipzig2Vec```.
#
# 1. Create a ```wiki2vec_emotion_dict``` dictionary by expanding the six nouns and six adjectives to the top 50 most similar using the Wiki2Vec embeddings.
# 2. Create a ```leipzig2vec_emotion_dict``` dictionary by expanding the six nouns and six adjectives to the top 50 most similar using the Leipzig2Vec embeddings.
# 3. For each noun-adjective pair, print the 50 most similar words for each Word2Vec model and the overlap.
# 4. How consistent are these most similar words?
# 5. How different are the lists across the models and compared to WordNet expanion?
# 6. For each pair of noun-adjective, how much overlap is there and is the overlap more consistent?

# %% [markdown]
# ### 2.1 Wiki2Vec expansion:

# %% [markdown]
# Download the Wiki2Vec embeddings for your target language and load the model using the Gensim package. If you cannot load the complete model, load part of it.
#
# ## TIP:
# You need to check if the emotion word actually is included in the vcabulary of the embedding model. If not, add an empty list of words to the dictionary.

# %% [markdown]
# ## [HERE COMES YOUR CODE TO EXPAND THE WORDS USING WIKI2VEC]

# %% [markdown]
# ## KEY:

# %%
import gensim
from gensim.models import KeyedVectors
# Path to the local copy of a model built from wikipedia
MODEL_FILE='/Users/piek/Desktop/t-ONDERWIJS/data/word-embeddings/wiki2vec/enwiki_20180420_100d.txt'

### If you have a small computer you may want to limit the number of embeddings loaded as shown below:
## wiki2vec = KeyedVectors.load_word2vec_format(MODEL_FILE, limit=5000) 

### To load the full model you should drop the limit.
# Loading the full model can take a while.
wiki2vec = KeyedVectors.load_word2vec_format(MODEL_FILE)

# %% [markdown]
# Get a list of the words that are most similar to the six basic emotions: sadness, fear, surprise, anger, joy and disgust.

# %%
wiki2vec_emotion_dict = {}

for noun in basic_emotions:
    words = []
    if noun in wiki2vec.key_to_index:
        sim50 = wiki2vec.most_similar(noun, topn=50)
        for sim in sim50:
            word = sim[0]
            if not word.startswith('ENTITY'):
                words.append(sim[0])
    wiki2vec_emotion_dict[noun]=words

for adjective in adjectival_basic_emotions:
    words = []
    if noun in wiki2vec.key_to_index:
        sim50 = wiki2vec.most_similar(adjective, topn=50)
        for sim in sim50:
            word = sim[0]
            if not word.startswith('ENTITY'):
                words.append(sim[0])
    wiki2vec_emotion_dict[adjective]=words

# %% [markdown]
# ### 2.2 Embeddings from the Leipzig corpus:

# %% [markdown]
# Download a text corpus from the Leipniz corpora collection. Build an embedding model from that corpus as explained in the notebook **Lab2.3.Creating_Wordembeddings** or load the model from disk if you already built and saved it.
#
# Get the words that are most similar to the six basic emotions in the same way as you did for the Wiki2vec embeddings.
#
# ## TIP:
# You need to check if the emotion word actually is included in the vcabulary of the embedding model. If not, add an empty list of words to the dictionary.

# %% [markdown]
# ## [HERE COMES YOUR CODE TO EXPAND THE WORDS USING LEIPZIG2VEC]

# %% [markdown]
# ## KEY:

# %%
leipzig2vec = KeyedVectors.load_word2vec_format('/Users/piek/Desktop/t-ONDERWIJS/data/leipzig-corpora/models/eng_news_2005_1M-sentences.txt')

# %%
leipzig_emotion_dict = {}

for noun in basic_emotions:
    words = []
    if noun in leipzig2vec.key_to_index:
        sim50 = leipzig2vec.most_similar(noun, topn=50)
        for sim in sim50:
            words.append(sim[0])
    leipzig_emotion_dict[noun]=words

for adjective in adjectival_basic_emotions:
    words = []
    if adjective in leipzig2vec.key_to_index:
        sim50 = leipzig2vec.most_similar(adjective, topn=50)
        for sim in sim50:
            words.append(sim[0])
    leipzig_emotion_dict[adjective]=words

# %% [markdown]
# ### 2.3. Comparison

# %% [markdown]
# ## [HERE COMES YOUR CODE TO PRINT THE EXPANDED WORDS FOR EACH MODEL AND THE OVERLAP]

# %%
for noun, adjective in zip(basic_emotions, adjectival_basic_emotions):
    wiki2vec_words = wiki2vec_emotion_dict[noun]
    leipzig2vec_words = leipzig_emotion_dict[noun]
    print(noun.upper())
    print(f"Wiki2Vec:{len(wiki2vec_words)}:{wiki2vec_words}")
    print(f"Leipzig2Vec:{len(leipzig2vec_words)}: {leipzig2vec_words}")
    overlap =list(set(wiki2vec_words) & set(leipzig2vec_words))
    print(f"Overlap: {len(overlap)}: {overlap}")
    print()

    
    wiki2vec_words = wiki2vec_emotion_dict[adjective]
    leipzig2vec_words = leipzig_emotion_dict[adjective]
    print(adjective.upper())
    print(f"Wiki2Vec:{len(wiki2vec_words)}:{wiki2vec_words}")
    print(f"Leipzig2Vec:{len(leipzig2vec_words)}: {leipzig2vec_words}")
    overlap =list(set(wiki2vec_words) & set(leipzig2vec_words))
    print(f"Overlap: {len(overlap)}: {overlap}")
    print()
# Out:
# SADNESS
# Wiki2Vec:50:['sorrow', 'anguish', 'loneliness', 'grief', 'despair', 'longing', 'yearning', 'feeling', 'despondency', 'hopelessness', 'regret', 'exhilaration', 'aushan', 'pensiveness', 'melancholy', 'anger', 'unhappiness', 'helplessness', 'weariness', 'ennui', 'gloominess', 'shame', 'hopefulness', 'frustration', 'feelings', 'remorse', 'anxieties', 'bewilderment', '解怨', 'elation', 'unease', 'disgust', 'exultation', 'emotion', 'optimism', 'bitterness', 'uneasiness', 'tempestuousness', 'restlessness', 'coldness', 'emotions', 'disillusionment', 'anxiousness', 'pessimism', 'disillusion', 'purposelessness', 'fear', 'contentment', 'dejection', 'tenderness']
# Leipzig2Vec:0: []
# Overlap: 0: []
#
# SAD
# Wiki2Vec:50:['okolinu', 'sirmijuma', 'geografske', 'karakteristike', 'rapajić', 'drugly', 'stanovnika', 'pronađi', 'bačke', 'zaboravit', 'juče', 'srema', 'verzija', 'gledaš', 'čoveka', 'dieingly', 'kasno', 'strukture', 'rastanak', 'podzemlje', 'uspomena', '슬픈', 'raickovic', 'tražim', 'banata', 'nježno', 'predeli', 'slutnja', 'prisajedinjenje', 'umoran', 'beograde', 'mladenoviću', 'hoće', 'sećanja', 'lijep', 'mržnja', 'svega', 'ljute', 'boarov', 'ljubavne', 'predratne', 'scenske', 'čujte', 'dlanu', 'srbinje', 'prolaze', 'svemir', 'paranoja', 'davnina', 'sjećanja']
# Leipzig2Vec:50: ['scary', 'shocking', 'strange', 'terrible', 'weird', 'horrible', 'sorry', 'frustrating', 'funny', 'ridiculous', 'satisfying', 'wonderful', 'okay', 'silly', 'unfortunate', 'amazing', 'nice', 'thankful', 'uncomfortable', 'ok', 'beautiful', 'happy', 'crazy', 'stupid', 'true', 'good', 'shocked', 'exciting', 'excited', 'unbelievable', 'tired', 'grateful', 'proud', 'interesting', 'cruel', 'obvious', 'surprising', 'fantastic', 'scared', 'embarrassed', 'thrilled', 'important', 'inevitable', 'awesome', 'bad', 'disappointed', 'great', 'joke', 'fascinating', 'lucky']
# Overlap: 0: []
#
# ANGER
# Wiki2Vec:50:['disgust', 'frustration', 'jealousy', 'grief', 'arrogance', 'unhappiness', 'resentment', 'indignation', 'hatred', 'anguish', 'desperation', 'despair', 'fear', 'scorn', 'unease', 'uneasiness', 'disdain', 'revulsion', 'bewilderment', 'despondency', 'displeasure', 'feelings', 'sadness', 'remorse', 'humiliation', 'fears', 'mistrust', 'embarrassment', 'impatience', 'rudeness', 'guilt', 'despondence', 'helplessness', 'shame', 'outrage', 'hostility', 'frustrations', 'bossiness', 'cynicism', 'selfishness', 'callousness', 'powerlessness', 'disrespectfulness', 'sullenness', 'distrust', 'bitterness', 'naivety', 'animosity', 'indifference', 'hopelessness']
# Leipzig2Vec:50: ['frustration', 'outrage', 'grief', 'confusion', 'feelings', 'anxiety', 'controversy', 'uncertainty', 'doubts', 'disappointment', 'fears', 'battles', 'turmoil', 'tensions', 'criticism', 'tension', 'concern', 'credibility', 'rhetoric', 'struggle', 'disputes', 'sympathy', 'beliefs', 'concerns', 'disagreement', 'attitudes', 'worries', 'troubles', 'differences', 'optimism', 'accusations', 'bitter', 'expressing', 'plight', 'conflicts', 'distress', 'conflict', 'dispute', 'emotions', 'nerves', 'racism', 'ordeal', 'actions', 'movements', 'aggression', 'objections', 'behaviour', 'chaos', 'difficulties', 'depression']
# Overlap: 5: ['fears', 'feelings', 'grief', 'frustration', 'outrage']
#
# ANGRY
# Wiki2Vec:50:['frightened', 'irate', 'indignant', 'enraged', 'annoyed', 'terrified', 'disgusted', 'infuriated', 'jealous', 'outraged', 'embarrassed', 'incredulous', 'exasperated', 'impatient', 'scared', 'furious', 'incensed', 'angrily', 'inebriated', 'frustrated', 'angered', 'unnerved', 'loudly', 'shocked', 'aghast', 'horrified', 'startled', 'flustered', 'humiliated', 'irritated', 'obnoxious', 'worried', 'fearful', 'agitated', 'distraught', 'resentful', 'disheartened', 'intimidated', 'overjoyed', 'amused', 'bewildered', 'panicking', 'elated', 'dumbfounded', 'offended', 'enraging', 'riled', 'panicked', 'insulted', 'unruly']
# Leipzig2Vec:50: ['enthusiastic', 'upset', 'unhappy', 'frustrated', 'confused', 'anxious', 'shocked', 'complaining', 'scared', 'uncomfortable', 'embarrassed', 'curious', 'passionate', 'skeptical', 'alarmed', 'laughing', 'cheering', 'nervous', 'disappointed', 'concerned', 'worried', 'tired', 'depressed', 'stunned', 'talking', 'greeted', 'cautious', 'shouting', 'smiling', 'cheered', 'furious', 'sick', 'wary', 'shouted', 'ordinary', 'thrilled', 'screaming', 'surprised', 'amazed', 'apparently', 'outrage', 'crazy', 'outspoken', 'unidentified', 'worrying', 'excited', 'yelled', 'anger', 'loud', 'abusive']
# Overlap: 6: ['shocked', 'furious', 'frustrated', 'embarrassed', 'worried', 'scared']
#
# DISGUST
# Wiki2Vec:50:['anger', 'frustration', 'disdain', 'revulsion', 'dislike', 'dismay', 'bewilderment', 'amazement', 'astonishment', 'distaste', 'displeasure', 'childishness', 'exasperation', 'unhappiness', 'annoyance', 'rudeness', 'arrogance', 'jealousy', 'unease', 'uneasiness', 'feelings', 'bafflement', 'disbelief', 'bossiness', 'impatience', 'naivete', 'reticence', 'hatred', 'naivety', 'disinterest', 'petulance', 'bashfulness', 'bitterness', 'cynicism', 'repugnance', 'anguish', 'despair', 'resentment', 'disrespectfulness', 'embarrassment', 'remorse', 'callousness', 'selfishness', 'indifference', 'awkwardness', 'indignation', 'coldness', 'scorn', 'fear', 'ambivalence']
# Leipzig2Vec:0: []
# Overlap: 0: []
#
# DISGUSTING
# Wiki2Vec:50:['torfe', 'loathsome', 'sickening', 'sidesplittingly', 'awful', 'brainless', 'horrible', 'tasteless', 'ridiculous', 'confoundingly', 'howlingly', 'gleefulness', 'gratingly', 'contemptibly', 'abhorrent', 'nauseating', 'splattery', 'unerotic', 'idiotic', 'cringeworthy', 'disgustingly', 'creepy', 'porny', 'reprehensibly', 'unfunny', 'unscary', 'upatkoon', 'downright', 'scary', 'oafs', 'filthy', 'crapulous', 'hilarious', 'gopping', 'moronically', 'cretinous', 'laughable', 'peerlessly', 'reprehensible', 'ludicrous', 'nastiness', 'stupefying', 'disgraceful', 'screamingly', 'bucketload', 'teensploitation', 'kidpic', 'fucking', 'frightening', 'horrifying']
# Leipzig2Vec:0: []
# Overlap: 0: []
#
# SURPRISE
# Wiki2Vec:50:['surprised', 'surprising', 'mechaputer', 'unexpected', 'yameisy', 'gegenstoße', 'rebuff', 'motosune', 'undeterred', 'resounding', 'elated', 'delight', 'nejiru', 'infuriated', 'disappointment', 'convincing', 'niespodzianka', 'heartened', 'futile', 'mistake', 'chance', 'unexpectedly', 'ironically', 'deslar', 'banyou', 'panicked', 'dispirited', 'robès', 'spoiling', 'distraction', 'stunned', 'dismayed', 'drokken', 'amazement', 'investorettes', 'provocated', 'anyway', 'foolhardy', 'overanxius', 'joukaen', 'discomfiture', 'epiriotes', 'minagith', 'dragit', 'makimona', 'jerashid', 'backfired', 'emboldened', 'disastrous', 'eagerness']
# Leipzig2Vec:50: ['disappointment', 'mistake', 'clue', 'reaction', 'shock', 'doubt', 'joke', 'indication', 'mood', 'stranger', 'hint', 'gesture', 'suggestion', 'mention', 'excuse', 'surprising', 'shame', 'consolation', 'conclusion', 'upset', 'apparent', 'surprises', 'accomplishment', 'hero', 'surprised', 'blessing', 'nightmare', 'reminder', 'comeback', 'reason', 'blow', 'gamble', 'expectation', 'true', 'reply', 'wonder', 'sympathy', 'breakthrough', 'moment', 'loser', 'shocking', 'obvious', 'optimism', 'evident', 'bit', 'departure', 'announcement', 'setback', 'picture', 'but']
# Overlap: 4: ['surprising', 'mistake', 'disappointment', 'surprised']
#
# SURPRISING
# Wiki2Vec:50:['convincing', 'surprisingly', 'remarkable', 'intriguing', 'unexpected', 'interesting', 'improbable', 'uncharacteristic', 'shocking', 'exciting', 'obvious', 'compelling', 'startling', 'undeniable', 'inconsequential', 'unsurprising', 'stunning', 'frustrating', 'unconvincing', 'amazingly', 'unlikely', 'disconcerting', 'puzzling', 'datedness', 'seemed', 'vanderweff', 'anticlimactic', 'oscarcast', 'disheartening', 'baffling', 'worthwhile', 'unsettling', 'fascinating', 'memorable', 'regrettable', 'impressive', 'surprise', 'dismaying', 'inexplicable', 'implausible', 'unbelievable', 'gratifying', 'offputting', 'admittedly', 'nonetheless', 'undeniably', 'underwhelming', 'unentertaining', 'unsurprisingly', 'tensest']
# Leipzig2Vec:50: ['uncommon', 'obvious', 'unusual', 'shocking', 'true', 'frustrating', 'ridiculous', 'surprised', 'funny', 'unfortunately', 'remarkable', 'sad', 'evident', 'bad', 'disappointed', 'disappointing', 'surprisingly', 'necessarily', 'precisely', 'strange', 'scary', 'amazing', 'bothered', 'inevitable', 'dramatic', 'satisfying', 'mention', 'complicated', 'clear', 'upset', 'interesting', 'stupid', 'overlooked', 'easy', 'painful', 'realizing', 'acceptable', 'compelling', 'forgotten', 'difficult', 'weird', 'unfortunate', 'impressive', 'surprise', 'boring', 'important', 'obviously', 'satisfied', 'consistent', 'promising']
# Overlap: 9: ['surprisingly', 'frustrating', 'shocking', 'compelling', 'obvious', 'remarkable', 'interesting', 'impressive', 'surprise']
#
# FEAR
# Wiki2Vec:50:['fears', 'despair', 'shame', 'revulsion', 'anger', 'hopelessness', 'paranoia', 'danger', 'lecherousness', 'misery', 'sei3ed', 'purposelessness', 'unreasoning', 'retribution', 'arrogance', 'ignorance', 'hatred', 'anguish', 'disgust', 'malevolence', 'boredom', 'uneasiness', 'helplessness', 'greed', 'guilt', 'stupidity', 'complacency', 'betrayal', 'remorse', 'desperation', 'defenselessness', 'faintheartedness', 'hurtfulness', 'viciousness', 'indifference', 'frustration', 'pyrophobia', 'maliciousness', 'murderousness', 'impatience', 'cynicism', 'jealousy', 'mistrust', 'avariciousness', 'pettiness', 'aushan', 'sunbane', 'torment', 'kashayas', 'phthonos']
# Leipzig2Vec:50: ['blame', 'doubt', 'danger', 'believe', 'believing', 'fears', 'cause', 'perception', 'argue', 'belief', 'feared', 'concern', 'hope', 'say', 'sympathy', 'regret', 'notion', 'suffer', 'realize', 'insist', 'feel', 'harm', 'fearing', 'suggest', 'worry', 'think', 'sense', 'frustration', 'wonder', 'struggle', 'acknowledge', 'extent', 'mean', 'anger', 'minds', 'know', 'likelihood', 'knowing', 'respect', 'disappointment', 'matter', 'consequences', 'warn', 'stress', 'problem', 'claim', 'influence', 'embarrassment', 'admit', 'shame']
# Overlap: 5: ['anger', 'danger', 'shame', 'fears', 'frustration']
#
# SCARY
# Wiki2Vec:50:['creepy', 'frightening', 'thankskilling', 'paralyzingly', 'spielbergian', 'uncomplicatedly', 'gobsmackingly', 'terrifying', 'batshit', 'splattery', 'funny', 'kooky', 'unspool', 'awful', 'scarier', 'cute', 'silly', 'sidesplitting', 'sidesplittingly', 'fun', 'horrible', 'verrry', 'mirthworms', 'vanderweff', 'creepiest', 'yucky', 'cloddish', 'hammier', 'hilarious', 'monsterettes', 'schlocky', 'unscary', 'weird', 'ghostliness', 'puppyish', 'fookin', 'underseen', 'dopier', 'teensploitation', 'ghastly', 'ugly', 'scaries', 'likably', 'moronically', 'plaguers', 'christmasy', 'cheeseball', 'frightener', 'frankenfido', 'serviceably']
# Leipzig2Vec:50: ['strange', 'weird', 'sad', 'silly', 'horrible', 'shocking', 'funny', 'frustrating', 'satisfying', 'terrible', 'stupid', 'boring', 'uncomfortable', 'ridiculous', 'crazy', 'gentle', 'neat', 'cute', 'tricky', 'lonely', 'amazing', 'cruel', 'humble', 'nasty', 'beautiful', 'clever', 'painful', 'pure', 'bad', 'wonderful', 'odd', 'thrill', 'fascinating', 'unfortunate', 'nice', 'okay', 'tired', 'compelling', 'unpredictable', 'bizarre', 'sexy', 'enjoyable', 'bleak', 'obvious', 'fabulous', 'scared', 'memorable', 'nervous', 'disturbing', 'rare']
# Overlap: 5: ['weird', 'funny', 'cute', 'silly', 'horrible']
#
# JOY
# Wiki2Vec:49:['grace', 'sorrow', 'śivam', 'unhearing', 'laughter', 'happiness', 'contentment', 'delight', 'love', 'sillaway', 'yearning', 'stehney', 'feeling', 'longing', 'c4mula', 'dreams', 'sadness', 'kecken', 'nostalg', 'bittersweetness', 'aryness', 'elation', 'upliftingly', 'santink', 'mckeaney', 'prayerfulness', 'cheerfulness', 'exhilaration', 'samvega', 'lathun', 'bliss', 'heartache', 'soundlessness', 'joyful', 'joys', 'loveliness', 'spectable', 'tylea', 'hopefulness', 'blissful', 'craving', 'hymnsong', 'fauldner', 'anguish', 'mirth', 'gladness', 'abicah', 'biddeth', 'ecstatic']
# Leipzig2Vec:50: ['soul', 'happiness', 'memories', 'grief', 'pride', 'passion', 'laughter', 'spirit', 'excitement', 'singing', 'jesus', 'love', 'humor', 'faith', 'lovely', 'smiles', 'romance', 'enthusiasm', 'pleasure', 'emotion', 'gospel', 'compassion', 'courage', 'affection', 'god', 'dad', 'gratitude', 'delight', 'loving', 'rhythm', 'sympathy', 'grace', 'tale', 'heaven', 'gentle', 'kiss', 'daddy', 'smiling', 'christ', 'horror', 'spiritual', 'smile', 'rap', 'dreams', 'dignity', 'congregation', 'princess', 'tears', 'portrait', 'friendship']
# Overlap: 6: ['grace', 'love', 'happiness', 'delight', 'laughter', 'dreams']
#
# HAPPY
# Wiki2Vec:45:['mirthworms', 'thrilled', 'lovely', 'outstaying', '행복한', 'skalidays', 'worshipfully', 'happiest', 'cotons', 'glad', 'happily', 'fun', 'snowbody', 'happier', 'ampstead', 'higyeong', '敢做', 'carefree', 'sorry', 'gulpje', 'politest', 'hmph', 'lucynell', 'rowr', 'heeey', 'miserable', 'funny', 'goodbye', 'santaville', 'darkeys', 'grandish', 'thripple', 'enjoyin', 'feckin', 'mudgin', 'perving', 'howlidays', 'iomg', 'wuzzlewood', 'crazy', 'cloddish', 'christmasy', 'loving', 'crevatte', 'snootful']
# Leipzig2Vec:50: ['pleased', 'thrilled', 'satisfied', 'excited', 'disappointed', 'delighted', 'thankful', 'proud', 'anxious', 'comfortable', 'glad', 'lucky', 'afraid', 'impressed', 'sorry', 'fortunate', 'careful', 'grateful', 'nice', 'surprised', 'keen', 'unhappy', 'good', 'sad', 'honest', 'frustrated', 'confident', 'going', 'blessed', 'embarrassed', 'sure', 'eager', 'optimistic', 'supportive', 'helpful', 'supposed', 'uncomfortable', 'ready', 'confused', 'willing', 'scared', 'hoping', 'quiet', 'ok', 'able', 'fun', 'cool', 'passionate', 'satisfying', 'familiar']
# Overlap: 4: ['glad', 'thrilled', 'fun', 'sorry']

# %% [markdown]
# ## [HERE COMES YOUR ANALYSIS AND DISCUSSION]

# %% [markdown]
# ## NRC Emotion lexicon

# %% [markdown]
# http://saifmohammad.com/WebPages/NRC-Emotion-Lexicon.htm

# %%
def load_nrc_lexicon(filepath):
    emotion_words = {}
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            word, emotion, score = line.strip().split('\t')
            if score == '1':
                if emotion in emotion_words:
                    emotion_words[emotion].append(word)
                else:
                    emotion_words[emotion] = [word]
    return {emo: sorted(words) for emo, words in emotion_words.items()}

filepath = "NRC-Emotion-Lexicon-Wordlevel-v0.92.txt"
nrc_emotion_lexicon = load_nrc_lexicon(filepath)

# %%
for noun, adjective in zip(basic_emotions, adjectival_basic_emotions):
    wordnet_nouns = wordnet_emotion_expansions[noun]
    wiki2vec_nouns = wiki2vec_emotion_dict[noun]
    leipzig2vec_nouns = leipzig_emotion_dict[noun]
    wordnet_adjectives = wordnet_emotion_expansions[adjective]
    wiki2vec_adjectives = wiki2vec_emotion_dict[adjective]
    leipzig2vec_adjectives = leipzig_emotion_dict[adjective]
    wordnet = set(wordnet_nouns+wordnet_adjectives)
    embedding = set(wiki2vec_nouns+leipzig2vec_nouns+wiki2vec_adjectives+leipzig2vec_adjectives)
    nrc = nrc_emotion_lexicon[noun]

    print(f"{noun.upper()}:")
    print(f"WORDNET:{len(wordnet)}")
    print(f"EMBEDDING:{len(embedding)}")
    print(f"NRC:{len(nrc)}")
    print("Overlap", list(set(wordnet)&set(nrc)&set(embedding)))
    print()
# Out:
# SADNESS:
# WORDNET:57
# EMBEDDING:150
# NRC:1187
# Overlap ['melancholy', 'regret', 'sorrow', 'unhappiness', 'loneliness', 'feeling', 'bad']
#
# ANGER:
# WORDNET:92
# EMBEDDING:188
# NRC:1245
# Overlap ['anger', 'furious', 'indignation', 'indignant', 'irate', 'outrage']
#
# DISGUST:
# WORDNET:51
# EMBEDDING:100
# NRC:1056
# Overlap ['revulsion', 'loathsome', 'dislike']
#
# SURPRISE:
# WORDNET:49
# EMBEDDING:178
# NRC:532
# Overlap ['surprise', 'surprising', 'shock', 'startling']
#
# FEAR:
# WORDNET:60
# EMBEDDING:190
# NRC:1474
# Overlap ['worry', 'thrill']
#
# JOY:
# WORDNET:53
# EMBEDDING:182
# NRC:687
# Overlap ['glad', 'excitement', 'blessed', 'exhilaration', 'joyful', 'happiness', 'delight', 'blissful']
