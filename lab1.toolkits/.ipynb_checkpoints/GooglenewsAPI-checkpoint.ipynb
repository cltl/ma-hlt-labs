# %% [markdown]
# https://pypi.org/project/GoogleNews/

# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews()

# %%
googlenews.search('Brexit')

# %%
result = googlenews.getpage(1)

# %%
print(result)
# Out:
# None

# %%
googlenews.result()
# Out:
# [{'title': 'Slakken, zalm en no deal-Brexit op het menu in Luxemburg',
#   'media': 'BNR Nieuwsradio',
#   'date': '4 uur geleden',
#   'desc': 'Inmiddels heeft Nigel Farage van de Britse Brexit Party al de verwachting uitgesproken dat de Brexit wordt uitgesteld. Hij gaat ervan uit dat het parlement\xa0...',
#   'link': 'https://www.bnr.nl/nieuws/internationaal/10389808/brexit-deal-zou-prachtig-zijn-maar-boris-kan-ook-zonder',
#   'img': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR-wmtgOqZ_cwRownRLcBlo4qo223B9RVRQ-OEwpxSNBCay3fPV-uNbGcTvBp5BLXXzNzaf2v8'},
#  {'title': "We stelden onze Britse collega's domme vragen over Brexit",
#   'media': 'VICE Nederland (Blog)',
#   'date': '1 uur geleden',
#   'desc': 'Hoe zit het met dat tweede referendum? En met de grens tussen Noord-Ierland en Ierland? En vanwaar al dat geschreeuw in het Britse\xa0...',
#   'link': 'https://www.vice.com/nl/article/7x5kba/we-stelden-onze-britse-collegas-domme-vragen-over-brexit',
# ...

# %%
googlenews.gettext()
# Out:
# ['Slakken, zalm en no deal-Brexit op het menu in Luxemburg',
#  "We stelden onze Britse collega's domme vragen over Brexit",
#  '47 dagen tot Brexit: Lagerhuis geschorst... of toch niet?',
#  'Document van regering-Johnson voorspelt chaos en rellen bij ...',
#  'Aftellen tot brexit: dit staat ons de komende 7 weken te wachten',
#  'Britse parlementsleden hebben geheim noodplan om brexit te ...',
#  'Britse regering in rapport: tekorten en chaos na no deal-brexit',
#  'Brexit: Johnson boekt “enorme vooruitgangen”',
#  'Brexit Impact Scan van FOD Economie al meer dan 25.000 ...',
#  "'Migranten riskeren leven in Het Kanaal vanwege brexit'",
#  '54 dagen tot Brexit: Dramaweek voor Johnson en ...',
#  "'Harde Brexit rampzalig voor Europees bedrijfsleven'",
#  'Douane meteen in actie bij no-deal Brexit',
#  "Johnson ziet mogelijke 'no-deal Brexit' als 'falen van ...",
#  "Johnson vraagt parlement niet voor 'zinloos Brexit-uitstel' te ...",
# ...

# %%
googlenews.getlinks()

# %%
googlenews.clear()
