# %% [markdown]
# # Lab 1.5 Interannotator agreement

# %% [markdown]
# Copyright: Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# Data for supervised machine learning is as good as its annotation. If the annotations are not correct or consistent than the data are no good for training and testing.
#
# This notebook shows how you can calculate the Inter-Annotator agreement (IAA) for the annotation of conversations with Llama3 for Lab0. There are three well-known methods to calculate the IAA: Cohen's kappa, Fleiss Kappa and Krippendorf's alpha. All three measures compare the agreement against the chance that the annotators accidently agree. Cohen and Fleiss compare the agreement against the expected agreement by chance and Krippendorf against the expected disagreement by chance. Cohen can only compare two annotators and nominal data, Fleiss more than two annotators of nominal data, Krippendorf more than two annotators and many different data types. In general, scores of 0.6 or higher are considerd to be of sufficient quality. If scores are lower, the annotations cannot be trusted.
#
# We will use the **metrics** module from NLTK which provides an **agreement.AnnotationTask** function to feed the data that needs to be compared. We will take the data from the annotated Llama conversations that are stored as JSON file. We first import **json** and the **NLTK** module.

# %%
import json
from  nltk.metrics import agreement

# %% [markdown]
# In the ```iaa``` folder, you find two annotations of the same conversation. The fake annotators are "Piek" and "Hennie". We can read the data from the file to create a json object for the original conversation with the two annotations.

# %%
# Assume JSON files with a conversation as a list of turns
# each turn as an Annotator and a Gold label field
# All conversations should have an equal number of turns

file1 = open("./iaa/annotator_Piek_human_Piek_chat_with_llama.json")
conversation1 = json.load(file1)

file2 = open("./iaa/annotator_Hennie_human_Piek_chat_with_llama.json")
conversation2 = json.load(file2)

print(len(conversation1), len(conversation2))
# Out:
# 35 35

# %% [markdown]
# By checking the length, we verify that the conversations have the same number of turns. The next function will extract a list of annotations from the data in the form of a tuple that consists of the name of the annotator, the turn identifier and the label. We are ignoring the turns uttered by an LLM, as these were annotated automatically as "neutral". In this example, the LLM is ```Llama```.

# %%
## This function takes as parameters a conversation in JSON format 
## and it returns a list of annotations in the form of a tuple:
## annotator, turn id, label
def get_chat_annotations(conversation=[]):
    annotations = []
    for turn in conversation:
        speaker = turn['speaker']
        turn_id = turn['turn_id']
        if not speaker=='Llama':
            annotator= turn['Annotator']
            gold = turn['Gold']
            annotations.append((annotator, turn_id, gold))
    return annotations

# %%
anno1 = get_chat_annotations(conversation1)
anno2 = get_chat_annotations(conversation2)
print(len(anno1), len(anno2))
for a1, a2 in zip(anno1, anno2):
    print(a1, a2)
# Out:
# 17 17
# ('Piek', 2, 'neutral') ('Hennie', 2, 'neutral')
# ('Piek', 4, 'sadness') ('Hennie', 4, 'joy')
# ('Piek', 6, 'sadness') ('Hennie', 6, 'fear')
# ('Piek', 8, 'joy') ('Hennie', 8, 'neutral')
# ('Piek', 10, 'joy') ('Hennie', 10, 'neutral')
# ('Piek', 12, 'neutral') ('Hennie', 12, 'joy')
# ('Piek', 14, 'sadness') ('Hennie', 14, 'neutral')
# ('Piek', 16, 'sadness') ('Hennie', 16, 'sadness')
# ('Piek', 18, 'neutral') ('Hennie', 18, 'surprise')
# ('Piek', 20, 'fear') ('Hennie', 20, 'fear')
# ('Piek', 22, 'joy') ('Hennie', 22, 'joy')
# ('Piek', 24, 'joy') ('Hennie', 24, 'joy')
# ('Piek', 26, 'fear') ('Hennie', 26, 'fear')
# ('Piek', 28, 'disgust') ('Hennie', 28, 'disgust')
# ('Piek', 30, 'fear') ('Hennie', 30, 'fear')
# ('Piek', 32, 'neutral') ('Hennie', 32, 'neutral')
# ('Piek', 34, 'neutral') ('Hennie', 34, 'neutral')

# %% [markdown]
# We extracted list of annotations with an equal length. By zipping both lists and getting the second element from the tuple for each pair, we can check if they have the same turn ids. Our data seems to be compatible. Now we can concatenate the two lists and call the **AnnotationTask** function with the combined data.

# %%
data = anno1+anno2
iaa = agreement.AnnotationTask(data=data)

print("Cohen's Kappa:", iaa.kappa())
print("Fleiss's Kappa:", iaa.multi_kappa())
print("Krippendorf's Kappa:", iaa.alpha())
# Out:
# Cohen's Kappa: 0.47345132743362833
# Fleiss's Kappa: 0.47345132743362833
# Krippendorf's Kappa: 0.48206278026905836

# %% [markdown]
# All three measures score below .6 so these two annotators disagree a lot. This means the annotation is not trustworthy and the annotation task needs to be reconsidered.
#
# You can easily see how you can do this for more than two annotators by extracting more annoations and concatenating these in data: data = ann1+anno2+anno3+anno4, etc.
#
# If you have a large crowd of annotations, you could take the majority vote as the adjudicated label. Next you can compare each annotator's labels against the adjudicated data set and validate the quality of the annotator.

# %% [markdown]
# ### IAA for student annotations

# %%
import pandas as pd

annotation_file = "/Users/piek/Desktop/t-MA-HLT-introduction-2025/ma-hlt-labs/lab1.chat/annotation/chats_2025/adjudicated_annotations.json"

df = pd.read_json(annotation_file)
df.head()
# Out:
#                                            utterance speaker  turn_id  \
# 0  Can you give me ideas on how to deal with some...    Bill        4
# 1  I am so angry. I am blind with rage. I want to...    Bill        6
# 2  But at the same time I am happy that it is ove...    Bill        8
# 3  When I found out I was so surprised. I saw no ...    Bill       10
# 4      Please do give me some steps to get over this    Bill       12
#
#        Gold Annotator                                              Votes  \
# 0   neutral      Rico  [neutral, neutral, sadness, sadness, neutral, ...
# 1     anger      Rico         [anger, anger, anger, anger, anger, anger]
# 2       joy      Rico                 [joy, joy, anger, anger, joy, joy]
# 3  surprise      Rico  [surprise, surprise, surprise, surprise, surpr...
# 4   neutral      Rico  [neutral, neutral, neutral, neutral, neutral, ...
#
#                                           Annotators Adjudication
# 0  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...      sadness
# 1  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...        anger
# 2  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...          joy
# 3  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...     surprise
# 4  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...      neutral

# %%
anno1 = []
anno2 = []
anno3 = []
for ind in df.index:
    vote = df['Votes'][ind]
    annotators = df['Annotators'][ind]
    turn_id = df['turn_id'][ind]
    speaker = df['speaker'][ind]
    key = speaker+"_"+str(turn_id)
    anno1.append((annotators[0], key, vote[0]))
    if len(vote)==3:
        anno2.append((annotators[1], key, vote[1]))
        anno3.append((annotators[2], key, vote[2]))
    elif len(vote)==2:
        anno2.append((annotators[1], key, vote[1]))
        anno3.append(("missing3", key, "missing"))
    else:
        anno2.append(("missing2", key, "missing"))
        anno3.append(("missing3", key, "missing"))
# Out:
# ('Rico', 'Bill_4', 'neutral') ('missing2', 'Bill_4', 'missing') ('missing3', 'Bill_4', 'missing')

# %%
data = anno1+anno2
iaa = agreement.AnnotationTask(data=data)
print("Krippendorf's alpha:", iaa.alpha())

data = anno1+anno3
iaa = agreement.AnnotationTask(data=data)
print("Krippendorf's alpha:", iaa.alpha())


data = anno2+anno3
iaa = agreement.AnnotationTask(data=data)
print("Krippendorf's alpha:", iaa.alpha())


data = anno1+anno2+anno3
iaa = agreement.AnnotationTask(data=data)
print("Krippendorf's alpha:", iaa.alpha())
# Out:
# Krippendorf's alpha: 0.377630235276729
# Krippendorf's alpha: 0.27840142401883383
# Krippendorf's alpha: 0.6103997909589758
# Krippendorf's alpha: 0.42834256293857953

# %%
for a1, a2, a3 in zip(anno1, anno2, anno3):
    print(a1, a2, a3)
# Out:
# ('Rico', 'Bill_4', 'neutral') ('missing2', 'Bill_4', 'missing') ('missing3', 'Bill_4', 'missing')
# ('Rico', 'Bill_6', 'anger') ('missing2', 'Bill_6', 'missing') ('missing3', 'Bill_6', 'missing')
# ('Rico', 'Bill_8', 'joy') ('missing2', 'Bill_8', 'missing') ('missing3', 'Bill_8', 'missing')
# ('Rico', 'Bill_10', 'surprise') ('missing2', 'Bill_10', 'missing') ('missing3', 'Bill_10', 'missing')
# ('Rico', 'Bill_12', 'neutral') ('missing2', 'Bill_12', 'missing') ('missing3', 'Bill_12', 'missing')
# ('Rico', 'Bill_14', 'neutral') ('missing2', 'Bill_14', 'missing') ('missing3', 'Bill_14', 'missing')
# ('Rico', 'Bill_16', 'joy') ('missing2', 'Bill_16', 'missing') ('missing3', 'Bill_16', 'missing')
# ('Rico', 'Bill_18', 'sadness') ('missing2', 'Bill_18', 'missing') ('missing3', 'Bill_18', 'missing')
# ('Rico', 'Bill_20', 'anger') ('missing2', 'Bill_20', 'missing') ('missing3', 'Bill_20', 'missing')
# ('Rico', 'Bill_22', 'anger') ('missing2', 'Bill_22', 'missing') ('missing3', 'Bill_22', 'missing')
# ('Rico', 'Bill_24', 'neutral') ('missing2', 'Bill_24', 'missing') ('missing3', 'Bill_24', 'missing')
# ('Rico', 'Bill_26', 'neutral') ('missing2', 'Bill_26', 'missing') ('missing3', 'Bill_26', 'missing')
# ('Rico', 'Bill_28', 'neutral') ('missing2', 'Bill_28', 'missing') ('missing3', 'Bill_28', 'missing')
# ('Rico', 'Bill_30', 'neutral') ('missing2', 'Bill_30', 'missing') ('missing3', 'Bill_30', 'missing')
# ('Rico', 'Bill_32', 'anger') ('missing2', 'Bill_32', 'missing') ('missing3', 'Bill_32', 'missing')
# ('Rico', 'Bill_2', 'anger') ('missing2', 'Bill_2', 'missing') ('missing3', 'Bill_2', 'missing')
# ('Rico', 'Joe_4', 'fear') ('missing2', 'Joe_4', 'missing') ('missing3', 'Joe_4', 'missing')
# ('Rico', 'Joe_6', 'neutral') ('missing2', 'Joe_6', 'missing') ('missing3', 'Joe_6', 'missing')
# ('Rico', 'Joe_8', 'joy') ('missing2', 'Joe_8', 'missing') ('missing3', 'Joe_8', 'missing')
# ('Rico', 'Joe_10', 'neutral') ('missing2', 'Joe_10', 'missing') ('missing3', 'Joe_10', 'missing')
# ('Rico', 'Joe_12', 'joy') ('missing2', 'Joe_12', 'missing') ('missing3', 'Joe_12', 'missing')
# ('Rico', 'Joe_14', 'anger') ('missing2', 'Joe_14', 'missing') ('missing3', 'Joe_14', 'missing')
# ('Rico', 'Joe_16', 'anger') ('missing2', 'Joe_16', 'missing') ('missing3', 'Joe_16', 'missing')
# ('Rico', 'Joe_18', 'anger') ('missing2', 'Joe_18', 'missing') ('missing3', 'Joe_18', 'missing')
# ('Rico', 'Joe_20', 'anger') ('missing2', 'Joe_20', 'missing') ('missing3', 'Joe_20', 'missing')
# ('Rico', 'Joe_22', 'anger') ('missing2', 'Joe_22', 'missing') ('missing3', 'Joe_22', 'missing')
# ('Rico', 'Joe_24', 'anger') ('missing2', 'Joe_24', 'missing') ('missing3', 'Joe_24', 'missing')
# ('Rico', 'Joe_26', 'neutral') ('missing2', 'Joe_26', 'missing') ('missing3', 'Joe_26', 'missing')
# ('Rico', 'Joe_28', 'neutral') ('missing2', 'Joe_28', 'missing') ('missing3', 'Joe_28', 'missing')
# ('Rico', 'Joe_30', 'sadness') ('missing2', 'Joe_30', 'missing') ('missing3', 'Joe_30', 'missing')
# ('Rico', 'Joe_32', 'neutral') ('missing2', 'Joe_32', 'missing') ('missing3', 'Joe_32', 'missing')
# ('Rico', 'Joe_34', 'sadness') ('missing2', 'Joe_34', 'missing') ('missing3', 'Joe_34', 'missing')
# ('Rico', 'Joe_36', 'neutral') ('missing2', 'Joe_36', 'missing') ('missing3', 'Joe_36', 'missing')
# ('Rico', 'Joe_38', 'joy') ('missing2', 'Joe_38', 'missing') ('missing3', 'Joe_38', 'missing')
# ('Rico', 'Joe_40', 'surprise') ('missing2', 'Joe_40', 'missing') ('missing3', 'Joe_40', 'missing')
# ('Rico', 'Joe_42', 'neutral') ('missing2', 'Joe_42', 'missing') ('missing3', 'Joe_42', 'missing')
# ('Rico', 'Joe_44', 'neutral') ('missing2', 'Joe_44', 'missing') ('missing3', 'Joe_44', 'missing')
# ('Rico', 'Joe_46', 'neutral') ('missing2', 'Joe_46', 'missing') ('missing3', 'Joe_46', 'missing')
# ('Rico', 'Joe_48', 'neutral') ('missing2', 'Joe_48', 'missing') ('missing3', 'Joe_48', 'missing')
# ('Rico', 'Jason_4', 'sadness') ('missing2', 'Jason_4', 'missing') ('missing3', 'Jason_4', 'missing')
# ('Rico', 'Jason_6', 'joy') ('missing2', 'Jason_6', 'missing') ('missing3', 'Jason_6', 'missing')
# ('Rico', 'Jason_8', 'neutral') ('missing2', 'Jason_8', 'missing') ('missing3', 'Jason_8', 'missing')
# ('Rico', 'Jason_10', 'neutral') ('missing2', 'Jason_10', 'missing') ('missing3', 'Jason_10', 'missing')
# ('Rico', 'Jason_12', 'neutral') ('missing2', 'Jason_12', 'missing') ('missing3', 'Jason_12', 'missing')
# ('Rico', 'Jason_14', 'joy') ('missing2', 'Jason_14', 'missing') ('missing3', 'Jason_14', 'missing')
# ('Rico', 'Jason_16', 'neutral') ('missing2', 'Jason_16', 'missing') ('missing3', 'Jason_16', 'missing')
# ('Rico', 'Jason_18', 'neutral') ('missing2', 'Jason_18', 'missing') ('missing3', 'Jason_18', 'missing')
# ('Rico', 'Jason_20', 'neutral') ('missing2', 'Jason_20', 'missing') ('missing3', 'Jason_20', 'missing')
# ('Rico', 'Jason_22', 'neutral') ('missing2', 'Jason_22', 'missing') ('missing3', 'Jason_22', 'missing')
# ('Rico', 'Jason_24', 'neutral') ('missing2', 'Jason_24', 'missing') ('missing3', 'Jason_24', 'missing')
# ('Rico', 'Jason_26', 'neutral') ('missing2', 'Jason_26', 'missing') ('missing3', 'Jason_26', 'missing')
# ('Rico', 'Jason_28', 'neutral') ('missing2', 'Jason_28', 'missing') ('missing3', 'Jason_28', 'missing')
# ('Rico', 'Jason_30', 'neutral') ('missing2', 'Jason_30', 'missing') ('missing3', 'Jason_30', 'missing')
# ('Rico', 'Jason_2', 'neutral') ('missing2', 'Jason_2', 'missing') ('missing3', 'Jason_2', 'missing')
# ('Rico', 'Dean_4', 'neutral') ('missing2', 'Dean_4', 'missing') ('missing3', 'Dean_4', 'missing')
# ('Rico', 'Dean_6', 'neutral') ('missing2', 'Dean_6', 'missing') ('missing3', 'Dean_6', 'missing')
# ('Rico', 'Dean_8', 'fear') ('missing2', 'Dean_8', 'missing') ('missing3', 'Dean_8', 'missing')
# ('Rico', 'Dean_10', 'fear') ('missing2', 'Dean_10', 'missing') ('missing3', 'Dean_10', 'missing')
# ('Rico', 'Dean_12', 'neutral') ('missing2', 'Dean_12', 'missing') ('missing3', 'Dean_12', 'missing')
# ('Rico', 'Dean_14', 'fear') ('missing2', 'Dean_14', 'missing') ('missing3', 'Dean_14', 'missing')
# ('Rico', 'Dean_16', 'joy') ('missing2', 'Dean_16', 'missing') ('missing3', 'Dean_16', 'missing')
# ('Rico', 'Dean_18', 'anger') ('missing2', 'Dean_18', 'missing') ('missing3', 'Dean_18', 'missing')
# ('Rico', 'Dean_20', 'neutral') ('missing2', 'Dean_20', 'missing') ('missing3', 'Dean_20', 'missing')
# ('Rico', 'Dean_22', 'neutral') ('missing2', 'Dean_22', 'missing') ('missing3', 'Dean_22', 'missing')
# ('Rico', 'Dean_24', 'neutral') ('missing2', 'Dean_24', 'missing') ('missing3', 'Dean_24', 'missing')
# ('Rico', 'Dean_26', 'neutral') ('missing2', 'Dean_26', 'missing') ('missing3', 'Dean_26', 'missing')
# ('Rico', 'Dean_28', 'neutral') ('missing2', 'Dean_28', 'missing') ('missing3', 'Dean_28', 'missing')
# ('Rico', 'Dean_30', 'neutral') ('missing2', 'Dean_30', 'missing') ('missing3', 'Dean_30', 'missing')
# ('Rico', 'Dean_32', 'neutral') ('missing2', 'Dean_32', 'missing') ('missing3', 'Dean_32', 'missing')
# ('Rico', 'Dean_34', 'joy') ('missing2', 'Dean_34', 'missing') ('missing3', 'Dean_34', 'missing')
# ('Rico', 'Dean_36', 'neutral') ('missing2', 'Dean_36', 'missing') ('missing3', 'Dean_36', 'missing')
# ('Rico', 'Dean_38', 'neutral') ('missing2', 'Dean_38', 'missing') ('missing3', 'Dean_38', 'missing')
# ('Rico', 'Dean_40', 'neutral') ('missing2', 'Dean_40', 'missing') ('missing3', 'Dean_40', 'missing')
# ('Rico', 'Dean_42', 'neutral') ('missing2', 'Dean_42', 'missing') ('missing3', 'Dean_42', 'missing')
# ('Rico', 'Dean_44', 'neutral') ('missing2', 'Dean_44', 'missing') ('missing3', 'Dean_44', 'missing')
# ('Rico', 'Dean_46', 'neutral') ('missing2', 'Dean_46', 'missing') ('missing3', 'Dean_46', 'missing')
# ('Rico', 'Dean_48', 'joy') ('missing2', 'Dean_48', 'missing') ('missing3', 'Dean_48', 'missing')
# ('Rico', 'Dean_50', 'neutral') ('missing2', 'Dean_50', 'missing') ('missing3', 'Dean_50', 'missing')
# ('Rico', 'Dean_2', 'neutral') ('missing2', 'Dean_2', 'missing') ('missing3', 'Dean_2', 'missing')
# ('Rico', 'Lennart_4', 'sadness') ('missing2', 'Lennart_4', 'missing') ('missing3', 'Lennart_4', 'missing')
# ('Rico', 'Lennart_6', 'neutral') ('missing2', 'Lennart_6', 'missing') ('missing3', 'Lennart_6', 'missing')
# ('Rico', 'Lennart_8', 'anger') ('missing2', 'Lennart_8', 'missing') ('missing3', 'Lennart_8', 'missing')
# ('Rico', 'Lennart_10', 'sadness') ('missing2', 'Lennart_10', 'missing') ('missing3', 'Lennart_10', 'missing')
# ('Rico', 'Lennart_12', 'sadness') ('missing2', 'Lennart_12', 'missing') ('missing3', 'Lennart_12', 'missing')
# ('Rico', 'Lennart_14', 'neutral') ('missing2', 'Lennart_14', 'missing') ('missing3', 'Lennart_14', 'missing')
# ('Rico', 'Lennart_16', 'joy') ('missing2', 'Lennart_16', 'missing') ('missing3', 'Lennart_16', 'missing')
# ('Rico', 'Lennart_18', 'joy') ('missing2', 'Lennart_18', 'missing') ('missing3', 'Lennart_18', 'missing')
# ('Rico', 'Lennart_20', 'neutral') ('missing2', 'Lennart_20', 'missing') ('missing3', 'Lennart_20', 'missing')
# ('Rico', 'Lennart_22', 'surprise') ('missing2', 'Lennart_22', 'missing') ('missing3', 'Lennart_22', 'missing')
# ('Rico', 'Lennart_24', 'neutral') ('missing2', 'Lennart_24', 'missing') ('missing3', 'Lennart_24', 'missing')
# ('Rico', 'Lennart_26', 'neutral') ('missing2', 'Lennart_26', 'missing') ('missing3', 'Lennart_26', 'missing')
# ('Rico', 'Lennart_28', 'neutral') ('missing2', 'Lennart_28', 'missing') ('missing3', 'Lennart_28', 'missing')
# ('Rico', 'Lennart_30', 'neutral') ('missing2', 'Lennart_30', 'missing') ('missing3', 'Lennart_30', 'missing')
# ('Rico', 'Lennart_32', 'neutral') ('missing2', 'Lennart_32', 'missing') ('missing3', 'Lennart_32', 'missing')
# ('Rico', 'Lennart_34', 'surprise') ('missing2', 'Lennart_34', 'missing') ('missing3', 'Lennart_34', 'missing')
# ('Rico', 'Lennart_36', 'neutral') ('missing2', 'Lennart_36', 'missing') ('missing3', 'Lennart_36', 'missing')
# ('Rico', 'Lennart_38', 'neutral') ('missing2', 'Lennart_38', 'missing') ('missing3', 'Lennart_38', 'missing')
# ('Rico', 'Lennart_40', 'neutral') ('missing2', 'Lennart_40', 'missing') ('missing3', 'Lennart_40', 'missing')
# ('Rico', 'Lennart_42', 'neutral') ('missing2', 'Lennart_42', 'missing') ('missing3', 'Lennart_42', 'missing')
# ('Rico', 'Lennart_44', 'neutral') ('missing2', 'Lennart_44', 'missing') ('missing3', 'Lennart_44', 'missing')
# ('Rico', 'Lennart_46', 'neutral') ('missing2', 'Lennart_46', 'missing') ('missing3', 'Lennart_46', 'missing')
# ('Rico', 'Lennart_48', 'sadness') ('missing2', 'Lennart_48', 'missing') ('missing3', 'Lennart_48', 'missing')
# ('Rico', 'Lennart_50', 'joy') ('missing2', 'Lennart_50', 'missing') ('missing3', 'Lennart_50', 'missing')
# ('Rico', 'Lennart_52', 'neutral') ('missing2', 'Lennart_52', 'missing') ('missing3', 'Lennart_52', 'missing')
# ('Rico', 'Lennart_54', 'neutral') ('missing2', 'Lennart_54', 'missing') ('missing3', 'Lennart_54', 'missing')
# ('Rico', 'Lennart_56', 'neutral') ('missing2', 'Lennart_56', 'missing') ('missing3', 'Lennart_56', 'missing')
# ('Rico', 'Lennart_58', 'neutral') ('missing2', 'Lennart_58', 'missing') ('missing3', 'Lennart_58', 'missing')
# ('Rico', 'Lennart_60', 'neutral') ('missing2', 'Lennart_60', 'missing') ('missing3', 'Lennart_60', 'missing')
# ('Rico', 'Lennart_62', 'surprise') ('missing2', 'Lennart_62', 'missing') ('missing3', 'Lennart_62', 'missing')
# ('Rico', 'Lennart_64', 'neutral') ('missing2', 'Lennart_64', 'missing') ('missing3', 'Lennart_64', 'missing')
# ('Rico', 'Lennart_66', 'neutral') ('missing2', 'Lennart_66', 'missing') ('missing3', 'Lennart_66', 'missing')
# ('Rico', 'Lennart_68', 'neutral') ('missing2', 'Lennart_68', 'missing') ('missing3', 'Lennart_68', 'missing')
# ('Rico', 'Lennart_70', 'neutral') ('missing2', 'Lennart_70', 'missing') ('missing3', 'Lennart_70', 'missing')
# ('Rico', 'Lennart_72', 'neutral') ('missing2', 'Lennart_72', 'missing') ('missing3', 'Lennart_72', 'missing')
# ('Rico', 'Lennart_74', 'neutral') ('missing2', 'Lennart_74', 'missing') ('missing3', 'Lennart_74', 'missing')
# ('Rico', 'Lennart_76', 'neutral') ('missing2', 'Lennart_76', 'missing') ('missing3', 'Lennart_76', 'missing')
# ('Rico', 'Lennart_78', 'fear') ('missing2', 'Lennart_78', 'missing') ('missing3', 'Lennart_78', 'missing')
# ('Rico', 'Lennart_80', 'neutral') ('missing2', 'Lennart_80', 'missing') ('missing3', 'Lennart_80', 'missing')
# ('Rico', 'Lennart_82', 'neutral') ('missing2', 'Lennart_82', 'missing') ('missing3', 'Lennart_82', 'missing')
# ('Rico', 'Lennart_84', 'neutral') ('missing2', 'Lennart_84', 'missing') ('missing3', 'Lennart_84', 'missing')
# ('Rico', 'Lennart_86', 'neutral') ('missing2', 'Lennart_86', 'missing') ('missing3', 'Lennart_86', 'missing')
# ('Marit', 'Ms. Potts_4', 'neutral') ('Keze', 'Ms. Potts_4', 'neutral') ('Manar', 'Ms. Potts_4', 'neutral')
# ('Marit', 'Ms. Potts_6', 'anger') ('Keze', 'Ms. Potts_6', 'anger') ('Manar', 'Ms. Potts_6', 'anger')
# ('Marit', 'Ms. Potts_8', 'anger') ('Keze', 'Ms. Potts_8', 'disgust') ('Manar', 'Ms. Potts_8', 'anger')
# ('Marit', 'Ms. Potts_10', 'anger') ('Keze', 'Ms. Potts_10', 'anger') ('Manar', 'Ms. Potts_10', 'anger')
# ('Marit', 'Ms. Potts_12', 'fear') ('Keze', 'Ms. Potts_12', 'fear') ('Manar', 'Ms. Potts_12', 'sadness')
# ('Marit', 'Ms. Potts_14', 'surprise') ('Keze', 'Ms. Potts_14', 'fear') ('Manar', 'Ms. Potts_14', 'fear')
# ('Marit', 'Ms. Potts_16', 'joy') ('Keze', 'Ms. Potts_16', 'joy') ('Manar', 'Ms. Potts_16', 'joy')
# ('Marit', 'Ms. Potts_18', 'anger') ('Keze', 'Ms. Potts_18', 'disgust') ('Manar', 'Ms. Potts_18', 'disgust')
# ('Marit', 'Ms. Potts_20', 'joy') ('Keze', 'Ms. Potts_20', 'joy') ('Manar', 'Ms. Potts_20', 'joy')
# ('Marit', 'Ms. Potts_22', 'sadness') ('Keze', 'Ms. Potts_22', 'sadness') ('Manar', 'Ms. Potts_22', 'sadness')
# ('Marit', 'Ms. Potts_24', 'anger') ('Keze', 'Ms. Potts_24', 'anger') ('Manar', 'Ms. Potts_24', 'anger')
# ('Marit', 'Ms. Potts_26', 'anger') ('Keze', 'Ms. Potts_26', 'anger') ('Manar', 'Ms. Potts_26', 'disgust')
# ('Marit', 'Ms. Potts_28', 'sadness') ('Keze', 'Ms. Potts_28', 'fear') ('Manar', 'Ms. Potts_28', 'fear')
# ('Marit', 'Ms. Potts_30', 'fear') ('Keze', 'Ms. Potts_30', 'surprise') ('Manar', 'Ms. Potts_30', 'fear')
# ('Marit', 'Ms. Potts_32', 'fear') ('Keze', 'Ms. Potts_32', 'fear') ('Manar', 'Ms. Potts_32', 'fear')
# ('Marit', 'Ms. Potts_34', 'neutral') ('Keze', 'Ms. Potts_34', 'neutral') ('Manar', 'Ms. Potts_34', 'neutral')
# ('Marit', 'Ms. Potts_36', 'joy') ('Keze', 'Ms. Potts_36', 'joy') ('Manar', 'Ms. Potts_36', 'neutral')
# ('Marit', 'Ms. Potts_38', 'neutral') ('Keze', 'Ms. Potts_38', 'neutral') ('Manar', 'Ms. Potts_38', 'joy')
# ('Marit', 'Ms. Potts_40', 'anger') ('Keze', 'Ms. Potts_40', 'anger') ('Manar', 'Ms. Potts_40', 'disgust')
# ('Marit', 'Ms. Potts_42', 'neutral') ('Keze', 'Ms. Potts_42', 'neutral') ('Manar', 'Ms. Potts_42', 'fear')
# ('Marit', 'Ms. Potts_44', 'neutral') ('Keze', 'Ms. Potts_44', 'neutral') ('Manar', 'Ms. Potts_44', 'neutral')
# ('Marit', 'Nymera Vaelith_4', 'neutral') ('Keze', 'Nymera Vaelith_4', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_4', 'neutral')
# ('Marit', 'Nymera Vaelith_6', 'neutral') ('Keze', 'Nymera Vaelith_6', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_6', 'sadness')
# ('Marit', 'Nymera Vaelith_8', 'sadness') ('Keze', 'Nymera Vaelith_8', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_8', 'sadness')
# ('Marit', 'Nymera Vaelith_10', 'neutral') ('Keze', 'Nymera Vaelith_10', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_10', 'neutral')
# ('Marit', 'Nymera Vaelith_12', 'fear') ('Keze', 'Nymera Vaelith_12', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_12', 'fear')
# ('Marit', 'Nymera Vaelith_14', 'neutral') ('Keze', 'Nymera Vaelith_14', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_14', 'neutral')
# ('Marit', 'Nymera Vaelith_16', 'neutral') ('Keze', 'Nymera Vaelith_16', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_16', 'neutral')
# ('Marit', 'Nymera Vaelith_18', 'anger') ('Keze', 'Nymera Vaelith_18', 'anger') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_18', 'anger')
# ('Marit', 'Nymera Vaelith_20', 'neutral') ('Keze', 'Nymera Vaelith_20', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_20', 'fear')
# ('Marit', 'Nymera Vaelith_22', 'neutral') ('Keze', 'Nymera Vaelith_22', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_22', 'fear')
# ('Marit', 'Nymera Vaelith_24', 'sadness') ('Keze', 'Nymera Vaelith_24', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_24', 'fear')
# ('Marit', 'Nymera Vaelith_26', 'neutral') ('Keze', 'Nymera Vaelith_26', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_26', 'neutral')
# ('Marit', 'Nymera Vaelith_28', 'neutral') ('Keze', 'Nymera Vaelith_28', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_28', 'neutral')
# ('Marit', 'Nymera Vaelith_30', 'sadness') ('Keze', 'Nymera Vaelith_30', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_30', 'sadness')
# ('Marit', 'Nymera Vaelith_32', 'sadness') ('Keze', 'Nymera Vaelith_32', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_32', 'sadness')
# ('Marit', 'Nymera Vaelith_34', 'sadness') ('Keze', 'Nymera Vaelith_34', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_34', 'sadness')
# ('Marit', 'Nymera Vaelith_36', 'neutral') ('Keze', 'Nymera Vaelith_36', 'anger') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_36', 'anger')
# ('Marit', 'Nymera Vaelith_38', 'sadness') ('Keze', 'Nymera Vaelith_38', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_38', 'fear')
# ('Marit', 'Nymera Vaelith_40', 'joy') ('Keze', 'Nymera Vaelith_40', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_40', 'joy')
# ('Marit', 'Nymera Vaelith_42', 'neutral') ('Keze', 'Nymera Vaelith_42', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Nymera Vaelith_42', 'neutral')
# ('Marit', 'Oek_4', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Oek_4', 'joy') ('Sanne', 'Oek_4', 'joy')
# ('Marit', 'Oek_6', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Oek_6', 'joy') ('Sanne', 'Oek_6', 'joy')
# ('Marit', 'Oek_8', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Oek_8', 'joy') ('Sanne', 'Oek_8', 'joy')
# ('Marit', 'Oek_10', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Oek_10', 'neutral') ('Sanne', 'Oek_10', 'neutral')
# ('Marit', 'Oek_12', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Oek_12', 'fear') ('Sanne', 'Oek_12', 'fear')
# ('Marit', 'Oek_14', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Oek_14', 'fear') ('Sanne', 'Oek_14', 'fear')
# ('Marit', 'Oek_16', 'anger') ('Masoumeh_Javadi_Zarnaghi', 'Oek_16', 'anger') ('Sanne', 'Oek_16', 'anger')
# ('Marit', 'Oek_18', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Oek_18', 'neutral') ('Sanne', 'Oek_18', 'fear')
# ('Marit', 'Oek_20', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Oek_20', 'neutral') ('Sanne', 'Oek_20', 'neutral')
# ('Marit', 'Oek_22', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Oek_22', 'joy') ('Sanne', 'Oek_22', 'joy')
# ('Marit', 'Oek_24', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Oek_24', 'joy') ('Sanne', 'Oek_24', 'joy')
# ('Marit', 'Oek_26', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Oek_26', 'sadness') ('Sanne', 'Oek_26', 'sadness')
# ('Marit', 'Oek_28', 'sadness') ('Masoumeh_Javadi_Zarnaghi', 'Oek_28', 'fear') ('Sanne', 'Oek_28', 'sadness')
# ('Marit', 'Oek_30', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Oek_30', 'joy') ('Sanne', 'Oek_30', 'joy')
# ('Marit', 'Oek_32', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Oek_32', 'joy') ('Sanne', 'Oek_32', 'joy')
# ('Marit', 'Oek_34', 'anger') ('Masoumeh_Javadi_Zarnaghi', 'Oek_34', 'anger') ('Sanne', 'Oek_34', 'sadness')
# ('Marit', 'Oek_36', 'surprise') ('Masoumeh_Javadi_Zarnaghi', 'Oek_36', 'surprise') ('Sanne', 'Oek_36', 'surprise')
# ('Marit', 'Oek_38', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Oek_38', 'surprise') ('Sanne', 'Oek_38', 'neutral')
# ('Marit', 'Oek_40', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Oek_40', 'joy') ('Sanne', 'Oek_40', 'joy')
# ('Marit', 'Oek_42', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Oek_42', 'neutral') ('Sanne', 'Oek_42', 'neutral')
# ('Giulia', 'Jackson_4', 'neutral') ('Bardia', 'Jackson_4', 'neutral') ('Piek', 'Jackson_4', 'neutral')
# ('Giulia', 'Jackson_6', 'sadness') ('Bardia', 'Jackson_6', 'sadness') ('Piek', 'Jackson_6', 'sadness')
# ('Giulia', 'Jackson_8', 'sadness') ('Bardia', 'Jackson_8', 'sadness') ('Piek', 'Jackson_8', 'sadness')
# ('Giulia', 'Jackson_10', 'neutral') ('Bardia', 'Jackson_10', 'surprise') ('Piek', 'Jackson_10', 'surprise')
# ('Giulia', 'Jackson_12', 'neutral') ('Bardia', 'Jackson_12', 'surprise') ('Piek', 'Jackson_12', 'neutral')
# ('Giulia', 'Jackson_14', 'surprise') ('Bardia', 'Jackson_14', 'surprise') ('Piek', 'Jackson_14', 'surprise')
# ('Giulia', 'Jackson_16', 'neutral') ('Bardia', 'Jackson_16', 'anger') ('Piek', 'Jackson_16', 'joy')
# ('Giulia', 'Jackson_18', 'anger') ('Bardia', 'Jackson_18', 'neutral') ('Piek', 'Jackson_18', 'anger')
# ('Giulia', 'Jackson_20', 'neutral') ('Bardia', 'Jackson_20', 'neutral') ('Piek', 'Jackson_20', 'anger')
# ('Giulia', 'Jackson_22', 'anger') ('Bardia', 'Jackson_22', 'anger') ('Piek', 'Jackson_22', 'anger')
# ('Giulia', 'Jackson_24', 'joy') ('Bardia', 'Jackson_24', 'joy') ('Piek', 'Jackson_24', 'joy')
# ('Giulia', 'Jackson_26', 'neutral') ('Bardia', 'Jackson_26', 'anger') ('Piek', 'Jackson_26', 'anger')
# ('Giulia', 'Jackson_28', 'neutral') ('Bardia', 'Jackson_28', 'anger') ('Piek', 'Jackson_28', 'anger')
# ('Giulia', 'Jackson_30', 'neutral') ('Bardia', 'Jackson_30', 'anger') ('Piek', 'Jackson_30', 'anger')
# ('Giulia', 'Jackson_32', 'neutral') ('Bardia', 'Jackson_32', 'neutral') ('Piek', 'Jackson_32', 'anger')
# ('Giulia', 'Jackson_34', 'neutral') ('Bardia', 'Jackson_34', 'neutral') ('Piek', 'Jackson_34', 'neutral')
# ('Giulia', 'Jackson_36', 'neutral') ('Bardia', 'Jackson_36', 'neutral') ('Piek', 'Jackson_36', 'neutral')
# ('Giulia', 'Jackson_38', 'neutral') ('Bardia', 'Jackson_38', 'surprise') ('Piek', 'Jackson_38', 'neutral')
# ('Giulia', 'Jackson_40', 'neutral') ('Bardia', 'Jackson_40', 'neutral') ('Piek', 'Jackson_40', 'neutral')
# ('Giulia', 'Jackson_42', 'neutral') ('Bardia', 'Jackson_42', 'joy') ('Piek', 'Jackson_42', 'neutral')
# ('Giulia', 'Jackson_44', 'neutral') ('Bardia', 'Jackson_44', 'neutral') ('Piek', 'Jackson_44', 'neutral')
# ('Giulia', 'Jackson_46', 'neutral') ('Bardia', 'Jackson_46', 'neutral') ('Piek', 'Jackson_46', 'neutral')
# ('Giulia', 'Jackson_48', 'neutral') ('Bardia', 'Jackson_48', 'neutral') ('Piek', 'Jackson_48', 'neutral')
# ('Giulia', 'Jackson_50', 'neutral') ('Bardia', 'Jackson_50', 'neutral') ('Piek', 'Jackson_50', 'neutral')
# ('Giulia', 'Jackson_52', 'joy') ('Bardia', 'Jackson_52', 'joy') ('Piek', 'Jackson_52', 'joy')
# ('Giulia', 'Jackson_54', 'neutral') ('Bardia', 'Jackson_54', 'joy') ('Piek', 'Jackson_54', 'neutral')
# ('Giulia', 'Jackson_56', 'neutral') ('Bardia', 'Jackson_56', 'joy') ('Piek', 'Jackson_56', 'neutral')
# ('Giulia', 'Jackson_58', 'joy') ('Bardia', 'Jackson_58', 'neutral') ('Piek', 'Jackson_58', 'neutral')
# ('Giulia', 'Jackson_60', 'neutral') ('Bardia', 'Jackson_60', 'neutral') ('Piek', 'Jackson_60', 'neutral')
# ('Giulia', 'Jake_4', 'sadness') ('Bardia', 'Jake_4', 'sadness') ('Thomas ', 'Jake_4', 'sadness')
# ('Giulia', 'Jake_6', 'sadness') ('Bardia', 'Jake_6', 'sadness') ('Thomas ', 'Jake_6', 'sadness')
# ('Giulia', 'Jake_8', 'joy') ('Bardia', 'Jake_8', 'joy') ('Thomas ', 'Jake_8', 'joy')
# ('Giulia', 'Jake_10', 'fear') ('Bardia', 'Jake_10', 'fear') ('Thomas ', 'Jake_10', 'fear')
# ('Giulia', 'Jake_12', 'surprise') ('Bardia', 'Jake_12', 'neutral') ('Thomas ', 'Jake_12', 'surprise')
# ('Giulia', 'Jake_14', 'sadness') ('Bardia', 'Jake_14', 'sadness') ('Thomas ', 'Jake_14', 'sadness')
# ('Giulia', 'Jake_16', 'neutral') ('Bardia', 'Jake_16', 'neutral') ('Thomas ', 'Jake_16', 'neutral')
# ('Giulia', 'Jake_18', 'neutral') ('Bardia', 'Jake_18', 'neutral') ('Thomas ', 'Jake_18', 'neutral')
# ('Giulia', 'Jake_20', 'neutral') ('Bardia', 'Jake_20', 'joy') ('Thomas ', 'Jake_20', 'neutral')
# ('Giulia', 'Jake_22', 'neutral') ('Bardia', 'Jake_22', 'neutral') ('Thomas ', 'Jake_22', 'neutral')
# ('Giulia', 'Jake_24', 'neutral') ('Bardia', 'Jake_24', 'neutral') ('Thomas ', 'Jake_24', 'surprise')
# ('Giulia', 'Jake_26', 'neutral') ('Bardia', 'Jake_26', 'surprise') ('Thomas ', 'Jake_26', 'neutral')
# ('Giulia', 'Jake_28', 'neutral') ('Bardia', 'Jake_28', 'surprise') ('Thomas ', 'Jake_28', 'neutral')
# ('Giulia', 'Jake_30', 'joy') ('Bardia', 'Jake_30', 'joy') ('Thomas ', 'Jake_30', 'joy')
# ('Giulia', 'Jake_32', 'joy') ('Bardia', 'Jake_32', 'joy') ('Thomas ', 'Jake_32', 'joy')
# ('Giulia', 'Jake_34', 'sadness') ('Bardia', 'Jake_34', 'sadness') ('Thomas ', 'Jake_34', 'sadness')
# ('Giulia', 'Jake_36', 'joy') ('Bardia', 'Jake_36', 'joy') ('Thomas ', 'Jake_36', 'joy')
# ('Giulia', 'Jake_38', 'neutral') ('Bardia', 'Jake_38', 'joy') ('Thomas ', 'Jake_38', 'joy')
# ('Giulia', 'Jake_40', 'neutral') ('Bardia', 'Jake_40', 'neutral') ('Thomas ', 'Jake_40', 'neutral')
# ('Giulia', 'Jake_42', 'neutral') ('Bardia', 'Jake_42', 'neutral') ('Thomas ', 'Jake_42', 'neutral')
# ('Giulia', 'Jake_44', 'neutral') ('Bardia', 'Jake_44', 'neutral') ('Thomas ', 'Jake_44', 'neutral')
# ('Popa', 'Star._4', 'neutral') ('Elmas', 'Star._4', 'sadness') ('missing3', 'Star._4', 'missing')
# ('Popa', 'Star._6', 'fear') ('Elmas', 'Star._6', 'fear') ('missing3', 'Star._6', 'missing')
# ('Popa', 'Star._8', 'fear') ('Elmas', 'Star._8', 'sadness') ('missing3', 'Star._8', 'missing')
# ('Popa', 'Star._10', 'joy') ('Elmas', 'Star._10', 'joy') ('missing3', 'Star._10', 'missing')
# ('Popa', 'Star._12', 'fear') ('Elmas', 'Star._12', 'fear') ('missing3', 'Star._12', 'missing')
# ('Popa', 'Star._14', 'fear') ('Elmas', 'Star._14', 'fear') ('missing3', 'Star._14', 'missing')
# ('Popa', 'Star._16', 'joy') ('Elmas', 'Star._16', 'surprise') ('missing3', 'Star._16', 'missing')
# ('Popa', 'Star._18', 'neutral') ('Elmas', 'Star._18', 'fear') ('missing3', 'Star._18', 'missing')
# ('Popa', 'Star._20', 'neutral') ('Elmas', 'Star._20', 'fear') ('missing3', 'Star._20', 'missing')
# ('Popa', 'Star._22', 'joy') ('Elmas', 'Star._22', 'joy') ('missing3', 'Star._22', 'missing')
# ('Popa', 'Star._24', 'sadness') ('Elmas', 'Star._24', 'sadness') ('missing3', 'Star._24', 'missing')
# ('Popa', 'Star._26', 'joy') ('Elmas', 'Star._26', 'neutral') ('missing3', 'Star._26', 'missing')
# ('Popa', 'Star._28', 'joy') ('Elmas', 'Star._28', 'surprise') ('missing3', 'Star._28', 'missing')
# ('Popa', 'Star._30', 'neutral') ('Elmas', 'Star._30', 'fear') ('missing3', 'Star._30', 'missing')
# ('Popa', 'Star._32', 'fear') ('Elmas', 'Star._32', 'fear') ('missing3', 'Star._32', 'missing')
# ('Popa', 'Star._34', 'sadness') ('Elmas', 'Star._34', 'sadness') ('missing3', 'Star._34', 'missing')
# ('Popa', 'Star._36', 'joy') ('Elmas', 'Star._36', 'fear') ('missing3', 'Star._36', 'missing')
# ('Popa', 'Star._38', 'neutral') ('Elmas', 'Star._38', 'fear') ('missing3', 'Star._38', 'missing')
# ('Popa', 'Star._40', 'neutral') ('Elmas', 'Star._40', 'fear') ('missing3', 'Star._40', 'missing')
# ('Popa', 'Star._42', 'joy') ('Elmas', 'Star._42', 'joy') ('missing3', 'Star._42', 'missing')
# ('Popa', 'Star._44', 'neutral') ('Elmas', 'Star._44', 'neutral') ('missing3', 'Star._44', 'missing')
# ('Popa', 'Star._46', 'joy') ('Elmas', 'Star._46', 'joy') ('missing3', 'Star._46', 'missing')
# ('Popa', 'Star._48', 'joy') ('Elmas', 'Star._48', 'surprise') ('missing3', 'Star._48', 'missing')
# ('Popa', 'Star._50', 'joy') ('Elmas', 'Star._50', 'joy') ('missing3', 'Star._50', 'missing')
# ('Popa', 'Star._52', 'neutral') ('Elmas', 'Star._52', 'neutral') ('missing3', 'Star._52', 'missing')
# ('Popa', 'Ada1_4', 'neutral') ('Vera Langeberg', 'Ada1_4', 'neutral') ('Gianmarco', 'Ada1_4', 'neutral')
# ('Popa', 'Ada1_6', 'neutral') ('Vera Langeberg', 'Ada1_6', 'joy') ('Gianmarco', 'Ada1_6', 'neutral')
# ('Popa', 'Ada1_8', 'neutral') ('Vera Langeberg', 'Ada1_8', 'sadness') ('Gianmarco', 'Ada1_8', 'neutral')
# ('Popa', 'Ada1_10', 'neutral') ('Vera Langeberg', 'Ada1_10', 'fear') ('Gianmarco', 'Ada1_10', 'surprise')
# ('Popa', 'Ada1_12', 'anger') ('Vera Langeberg', 'Ada1_12', 'fear') ('Gianmarco', 'Ada1_12', 'surprise')
# ('Popa', 'Ada1_14', 'neutral') ('Vera Langeberg', 'Ada1_14', 'anger') ('Gianmarco', 'Ada1_14', 'neutral')
# ('Popa', 'Ada1_16', 'neutral') ('Vera Langeberg', 'Ada1_16', 'neutral') ('Gianmarco', 'Ada1_16', 'anger')
# ('Popa', 'Ada1_2', 'neutral') ('Vera Langeberg', 'Ada1_2', 'neutral') ('Gianmarco', 'Ada1_2', 'neutral')
# ('Popa', 'Ada1_18', 'neutral') ('Vera Langeberg', 'Ada1_18', 'neutral') ('Gianmarco', 'Ada1_18', 'neutral')
# ('Popa', 'Ada1_20', 'joy') ('Vera Langeberg', 'Ada1_20', 'joy') ('Gianmarco', 'Ada1_20', 'joy')
# ('Popa', 'Ada1_22', 'neutral') ('Vera Langeberg', 'Ada1_22', 'joy') ('Gianmarco', 'Ada1_22', 'joy')
# ('Popa', 'Ada1_24', 'joy') ('Vera Langeberg', 'Ada1_24', 'joy') ('Gianmarco', 'Ada1_24', 'joy')
# ('Popa', 'Ada1_26', 'anger') ('Vera Langeberg', 'Ada1_26', 'anger') ('Gianmarco', 'Ada1_26', 'anger')
# ('Popa', 'Ada1_28', 'anger') ('Vera Langeberg', 'Ada1_28', 'anger') ('Gianmarco', 'Ada1_28', 'anger')
# ('Popa', 'Ada1_30', 'anger') ('Vera Langeberg', 'Ada1_30', 'fear') ('Gianmarco', 'Ada1_30', 'anger')
# ('Popa', 'Ada1_32', 'fear') ('Vera Langeberg', 'Ada1_32', 'fear') ('Gianmarco', 'Ada1_32', 'fear')
# ('Popa', 'Ada1_34', 'neutral') ('Vera Langeberg', 'Ada1_34', 'neutral') ('Gianmarco', 'Ada1_34', 'neutral')
# ('Popa', 'Ada1_36', 'neutral') ('Vera Langeberg', 'Ada1_36', 'neutral') ('Gianmarco', 'Ada1_36', 'disgust')
# ('Popa', 'Ada1_38', 'neutral') ('Vera Langeberg', 'Ada1_38', 'neutral') ('Gianmarco', 'Ada1_38', 'sadness')
# ('Popa', 'Ada1_40', 'joy') ('Vera Langeberg', 'Ada1_40', 'neutral') ('Gianmarco', 'Ada1_40', 'neutral')
# ('Popa', 'Woland_4', 'joy') ('Elmas', 'Woland_4', 'joy') ('Gianmarco', 'Woland_4', 'joy')
# ('Popa', 'Woland_6', 'neutral') ('Elmas', 'Woland_6', 'joy') ('Gianmarco', 'Woland_6', 'joy')
# ('Popa', 'Woland_8', 'joy') ('Elmas', 'Woland_8', 'joy') ('Gianmarco', 'Woland_8', 'joy')
# ('Popa', 'Woland_10', 'sadness') ('Elmas', 'Woland_10', 'sadness') ('Gianmarco', 'Woland_10', 'sadness')
# ('Popa', 'Woland_12', 'neutral') ('Elmas', 'Woland_12', 'joy') ('Gianmarco', 'Woland_12', 'neutral')
# ('Popa', 'Woland_14', 'fear') ('Elmas', 'Woland_14', 'anger') ('Gianmarco', 'Woland_14', 'fear')
# ('Popa', 'Woland_16', 'fear') ('Elmas', 'Woland_16', 'fear') ('Gianmarco', 'Woland_16', 'fear')
# ('Popa', 'Woland_18', 'fear') ('Elmas', 'Woland_18', 'fear') ('Gianmarco', 'Woland_18', 'fear')
# ('Popa', 'Woland_20', 'fear') ('Elmas', 'Woland_20', 'fear') ('Gianmarco', 'Woland_20', 'fear')
# ('Popa', 'Woland_22', 'fear') ('Elmas', 'Woland_22', 'fear') ('Gianmarco', 'Woland_22', 'sadness')
# ('Popa', 'Woland_24', 'fear') ('Elmas', 'Woland_24', 'fear') ('Gianmarco', 'Woland_24', 'fear')
# ('Popa', 'Woland_26', 'neutral') ('Elmas', 'Woland_26', 'fear') ('Gianmarco', 'Woland_26', 'neutral')
# ('Popa', 'Woland_28', 'fear') ('Elmas', 'Woland_28', 'fear') ('Gianmarco', 'Woland_28', 'sadness')
# ('Popa', 'Woland_30', 'fear') ('Elmas', 'Woland_30', 'sadness') ('Gianmarco', 'Woland_30', 'sadness')
# ('Popa', 'Woland_32', 'surprise') ('Elmas', 'Woland_32', 'sadness') ('Gianmarco', 'Woland_32', 'sadness')
# ('Popa', 'Woland_34', 'neutral') ('Elmas', 'Woland_34', 'sadness') ('Gianmarco', 'Woland_34', 'neutral')
# ('Popa', 'Woland_36', 'surprise') ('Elmas', 'Woland_36', 'sadness') ('Gianmarco', 'Woland_36', 'neutral')
# ('Popa', 'Woland_38', 'neutral') ('Elmas', 'Woland_38', 'neutral') ('Gianmarco', 'Woland_38', 'sadness')
# ('Popa', 'Woland_40', 'neutral') ('Elmas', 'Woland_40', 'neutral') ('Gianmarco', 'Woland_40', 'neutral')
# ('Popa', 'Woland_42', 'sadness') ('Elmas', 'Woland_42', 'neutral') ('Gianmarco', 'Woland_42', 'sadness')
# ('Vera Langeberg', 'Ada2_4', 'anger') ('zia', 'Ada2_4', 'anger') ('Gianmarco', 'Ada2_4', 'surprise')
# ('Vera Langeberg', 'Ada2_6', 'neutral') ('zia', 'Ada2_6', 'surprise') ('Gianmarco', 'Ada2_6', 'surprise')
# ('Vera Langeberg', 'Ada2_8', 'sadness') ('zia', 'Ada2_8', 'sadness') ('Gianmarco', 'Ada2_8', 'sadness')
# ('Vera Langeberg', 'Ada2_10', 'sadness') ('zia', 'Ada2_10', 'sadness') ('Gianmarco', 'Ada2_10', 'sadness')
# ('Vera Langeberg', 'Ada2_12', 'sadness') ('zia', 'Ada2_12', 'sadness') ('Gianmarco', 'Ada2_12', 'sadness')
# ('Vera Langeberg', 'Ada2_14', 'anger') ('zia', 'Ada2_14', 'anger') ('Gianmarco', 'Ada2_14', 'sadness')
# ('Vera Langeberg', 'Ada2_16', 'anger') ('zia', 'Ada2_16', 'anger') ('Gianmarco', 'Ada2_16', 'anger')
# ('Vera Langeberg', 'Ada2_18', 'neutral') ('zia', 'Ada2_18', 'fear') ('Gianmarco', 'Ada2_18', 'surprise')
# ('Vera Langeberg', 'Ada2_20', 'surprise') ('zia', 'Ada2_20', 'neutral') ('Gianmarco', 'Ada2_20', 'neutral')
# ('Vera Langeberg', 'Ada2_22', 'neutral') ('zia', 'Ada2_22', 'anger') ('Gianmarco', 'Ada2_22', 'neutral')
# ('Vera Langeberg', 'Ada2_24', 'neutral') ('zia', 'Ada2_24', 'sadness') ('Gianmarco', 'Ada2_24', 'joy')
# ('Vera Langeberg', 'Ada2_26', 'anger') ('zia', 'Ada2_26', 'anger') ('Gianmarco', 'Ada2_26', 'anger')
# ('Vera Langeberg', 'Ada2_28', 'anger') ('zia', 'Ada2_28', 'disgust') ('Gianmarco', 'Ada2_28', 'anger')
# ('Vera Langeberg', 'Ada2_30', 'neutral') ('zia', 'Ada2_30', 'neutral') ('Gianmarco', 'Ada2_30', 'neutral')
# ('Vera Langeberg', 'Ada2_32', 'joy') ('zia', 'Ada2_32', 'joy') ('Gianmarco', 'Ada2_32', 'joy')
# ('Vera Langeberg', 'Ada2_34', 'neutral') ('zia', 'Ada2_34', 'joy') ('Gianmarco', 'Ada2_34', 'joy')
# ('Vera Langeberg', 'Ada2_36', 'neutral') ('zia', 'Ada2_36', 'neutral') ('Gianmarco', 'Ada2_36', 'surprise')
# ('Vera Langeberg', 'Ada2_38', 'anger') ('zia', 'Ada2_38', 'disgust') ('Gianmarco', 'Ada2_38', 'anger')
# ('Vera Langeberg', 'Ada2_40', 'neutral') ('zia', 'Ada2_40', 'anger') ('Gianmarco', 'Ada2_40', 'neutral')
# ('anna westland', 'Bizmuth_4', 'joy') ('Ella', 'Bizmuth_4', 'joy') ('zia', 'Bizmuth_4', 'joy')
# ('anna westland', 'Bizmuth_6', 'fear') ('Ella', 'Bizmuth_6', 'fear') ('zia', 'Bizmuth_6', 'fear')
# ('anna westland', 'Bizmuth_8', 'anger') ('Ella', 'Bizmuth_8', 'anger') ('zia', 'Bizmuth_8', 'surprise')
# ('anna westland', 'Bizmuth_10', 'joy') ('Ella', 'Bizmuth_10', 'joy') ('zia', 'Bizmuth_10', 'joy')
# ('anna westland', 'Bizmuth_12', 'neutral') ('Ella', 'Bizmuth_12', 'neutral') ('zia', 'Bizmuth_12', 'neutral')
# ('anna westland', 'Bizmuth_14', 'neutral') ('Ella', 'Bizmuth_14', 'surprise') ('zia', 'Bizmuth_14', 'surprise')
# ('anna westland', 'Bizmuth_16', 'fear') ('Ella', 'Bizmuth_16', 'fear') ('zia', 'Bizmuth_16', 'fear')
# ('anna westland', 'Bizmuth_18', 'anger') ('Ella', 'Bizmuth_18', 'anger') ('zia', 'Bizmuth_18', 'anger')
# ('anna westland', 'Bizmuth_20', 'joy') ('Ella', 'Bizmuth_20', 'joy') ('zia', 'Bizmuth_20', 'joy')
# ('anna westland', 'Bizmuth_22', 'neutral') ('Ella', 'Bizmuth_22', 'neutral') ('zia', 'Bizmuth_22', 'neutral')
# ('anna westland', 'Bizmuth_24', 'neutral') ('Ella', 'Bizmuth_24', 'neutral') ('zia', 'Bizmuth_24', 'surprise')
# ('anna westland', 'Bizmuth_26', 'neutral') ('Ella', 'Bizmuth_26', 'neutral') ('zia', 'Bizmuth_26', 'neutral')
# ('anna westland', 'Bizmuth_28', 'neutral') ('Ella', 'Bizmuth_28', 'neutral') ('zia', 'Bizmuth_28', 'neutral')
# ('anna westland', 'Bizmuth_30', 'anger') ('Ella', 'Bizmuth_30', 'anger') ('zia', 'Bizmuth_30', 'disgust')
# ('anna westland', 'Bizmuth_32', 'anger') ('Ella', 'Bizmuth_32', 'anger') ('zia', 'Bizmuth_32', 'anger')
# ('anna westland', 'Bizmuth_34', 'sadness') ('Ella', 'Bizmuth_34', 'sadness') ('zia', 'Bizmuth_34', 'sadness')
# ('anna westland', 'Bizmuth_36', 'neutral') ('Ella', 'Bizmuth_36', 'neutral') ('zia', 'Bizmuth_36', 'neutral')
# ('anna westland', 'Bizmuth_38', 'neutral') ('Ella', 'Bizmuth_38', 'neutral') ('zia', 'Bizmuth_38', 'neutral')
# ('anna westland', 'Bizmuth_40', 'neutral') ('Ella', 'Bizmuth_40', 'neutral') ('zia', 'Bizmuth_40', 'neutral')
# ('anna westland', 'Brenda_2', 'neutral') ('Ella', 'Brenda_2', 'neutral') ('Marie Necker', 'Brenda_2', 'neutral')
# ('anna westland', 'Brenda_4', 'sadness') ('Ella', 'Brenda_4', 'sadness') ('Marie Necker', 'Brenda_4', 'sadness')
# ('anna westland', 'Brenda_6', 'neutral') ('Ella', 'Brenda_6', 'fear') ('Marie Necker', 'Brenda_6', 'neutral')
# ('anna westland', 'Brenda_8', 'anger') ('Ella', 'Brenda_8', 'anger') ('Marie Necker', 'Brenda_8', 'anger')
# ('anna westland', 'Brenda_10', 'anger') ('Ella', 'Brenda_10', 'anger') ('Marie Necker', 'Brenda_10', 'anger')
# ('anna westland', 'Brenda_12', 'anger') ('Ella', 'Brenda_12', 'anger') ('Marie Necker', 'Brenda_12', 'neutral')
# ('anna westland', 'Brenda_14', 'sadness') ('Ella', 'Brenda_14', 'sadness') ('Marie Necker', 'Brenda_14', 'sadness')
# ('anna westland', 'Brenda_16', 'anger') ('Ella', 'Brenda_16', 'anger') ('Marie Necker', 'Brenda_16', 'anger')
# ('anna westland', 'Brenda_18', 'anger') ('Ella', 'Brenda_18', 'anger') ('Marie Necker', 'Brenda_18', 'anger')
# ('anna westland', 'Brenda_20', 'anger') ('Ella', 'Brenda_20', 'anger') ('Marie Necker', 'Brenda_20', 'anger')
# ('anna westland', 'Brenda_22', 'anger') ('Ella', 'Brenda_22', 'anger') ('Marie Necker', 'Brenda_22', 'anger')
# ('anna westland', 'Brenda_24', 'sadness') ('Ella', 'Brenda_24', 'disgust') ('Marie Necker', 'Brenda_24', 'neutral')
# ('anna westland', 'Brenda_26', 'anger') ('Ella', 'Brenda_26', 'anger') ('Marie Necker', 'Brenda_26', 'anger')
# ('anna westland', 'Brenda_28', 'anger') ('Ella', 'Brenda_28', 'anger') ('Marie Necker', 'Brenda_28', 'anger')
# ('anna westland', 'Brenda_30', 'neutral') ('Ella', 'Brenda_30', 'joy') ('Marie Necker', 'Brenda_30', 'joy')
# ('anna westland', 'Brenda_32', 'joy') ('Ella', 'Brenda_32', 'surprise') ('Marie Necker', 'Brenda_32', 'surprise')
# ('anna westland', 'Brenda_34', 'disgust') ('Ella', 'Brenda_34', 'disgust') ('Marie Necker', 'Brenda_34', 'disgust')
# ('anna westland', 'Brenda_36', 'neutral') ('Ella', 'Brenda_36', 'neutral') ('Marie Necker', 'Brenda_36', 'neutral')
# ('anna westland', 'Brenda_38', 'joy') ('Ella', 'Brenda_38', 'surprise') ('Marie Necker', 'Brenda_38', 'surprise')
# ('anna westland', 'Brenda_40', 'joy') ('Ella', 'Brenda_40', 'joy') ('Marie Necker', 'Brenda_40', 'joy')
# ('anna westland', 'Brenda_42', 'joy') ('Ella', 'Brenda_42', 'joy') ('Marie Necker', 'Brenda_42', 'joy')
# ('anna westland', 'Brenda_44', 'anger') ('Ella', 'Brenda_44', 'disgust') ('Marie Necker', 'Brenda_44', 'anger')
# ('anna westland', 'Brenda_46', 'neutral') ('Ella', 'Brenda_46', 'neutral') ('Marie Necker', 'Brenda_46', 'neutral')
# ('anna westland', 'Brenda_48', 'neutral') ('Ella', 'Brenda_48', 'neutral') ('Marie Necker', 'Brenda_48', 'neutral')
# ('anna westland', 'Carla_4', 'neutral') ('Marie Necker', 'Carla_4', 'neutral') ('Reihane Rashid', 'Carla_4', 'anger')
# ('anna westland', 'Carla_6', 'fear') ('Marie Necker', 'Carla_6', 'neutral') ('Reihane Rashid', 'Carla_6', 'sadness')
# ('anna westland', 'Carla_8', 'neutral') ('Marie Necker', 'Carla_8', 'neutral') ('Reihane Rashid', 'Carla_8', 'neutral')
# ('anna westland', 'Carla_10', 'joy') ('Marie Necker', 'Carla_10', 'joy') ('Reihane Rashid', 'Carla_10', 'joy')
# ('anna westland', 'Carla_12', 'joy') ('Marie Necker', 'Carla_12', 'joy') ('Reihane Rashid', 'Carla_12', 'joy')
# ('anna westland', 'Carla_14', 'joy') ('Marie Necker', 'Carla_14', 'joy') ('Reihane Rashid', 'Carla_14', 'joy')
# ('anna westland', 'Carla_16', 'sadness') ('Marie Necker', 'Carla_16', 'fear') ('Reihane Rashid', 'Carla_16', 'fear')
# ('anna westland', 'Carla_18', 'neutral') ('Marie Necker', 'Carla_18', 'neutral') ('Reihane Rashid', 'Carla_18', 'neutral')
# ('anna westland', 'Carla_20', 'neutral') ('Marie Necker', 'Carla_20', 'neutral') ('Reihane Rashid', 'Carla_20', 'neutral')
# ('anna westland', 'Carla_22', 'fear') ('Marie Necker', 'Carla_22', 'fear') ('Reihane Rashid', 'Carla_22', 'fear')
# ('anna westland', 'Carla_24', 'fear') ('Marie Necker', 'Carla_24', 'fear') ('Reihane Rashid', 'Carla_24', 'fear')
# ('anna westland', 'Carla_26', 'fear') ('Marie Necker', 'Carla_26', 'fear') ('Reihane Rashid', 'Carla_26', 'fear')
# ('anna westland', 'Carla_28', 'neutral') ('Marie Necker', 'Carla_28', 'neutral') ('Reihane Rashid', 'Carla_28', 'neutral')
# ('anna westland', 'Carla_30', 'neutral') ('Marie Necker', 'Carla_30', 'neutral') ('Reihane Rashid', 'Carla_30', 'neutral')
# ('anna westland', 'Carla_32', 'neutral') ('Marie Necker', 'Carla_32', 'neutral') ('Reihane Rashid', 'Carla_32', 'neutral')
# ('anna westland', 'Carla_34', 'neutral') ('Marie Necker', 'Carla_34', 'neutral') ('Reihane Rashid', 'Carla_34', 'neutral')
# ('anna westland', 'Carla_36', 'anger') ('Marie Necker', 'Carla_36', 'anger') ('Reihane Rashid', 'Carla_36', 'anger')
# ('anna westland', 'Carla_38', 'surprise') ('Marie Necker', 'Carla_38', 'neutral') ('Reihane Rashid', 'Carla_38', 'surprise')
# ('anna westland', 'Carla_40', 'sadness') ('Marie Necker', 'Carla_40', 'neutral') ('Reihane Rashid', 'Carla_40', 'neutral')
# ('anna westland', 'Carla_42', 'sadness') ('Marie Necker', 'Carla_42', 'neutral') ('Reihane Rashid', 'Carla_42', 'neutral')
# ('anna westland', 'Carla_44', 'sadness') ('Marie Necker', 'Carla_44', 'neutral') ('Reihane Rashid', 'Carla_44', 'neutral')
# ('anna westland', 'Carla_46', 'neutral') ('Marie Necker', 'Carla_46', 'fear') ('Reihane Rashid', 'Carla_46', 'fear')
# ('anna westland', 'Carla_48', 'sadness') ('Marie Necker', 'Carla_48', 'fear') ('Reihane Rashid', 'Carla_48', 'fear')
# ('anna westland', 'Carla_50', 'sadness') ('Marie Necker', 'Carla_50', 'fear') ('Reihane Rashid', 'Carla_50', 'fear')
# ('anna westland', 'Carla_52', 'joy') ('Marie Necker', 'Carla_52', 'joy') ('Reihane Rashid', 'Carla_52', 'joy')
# ('anna westland', 'Carla_54', 'joy') ('Marie Necker', 'Carla_54', 'joy') ('Reihane Rashid', 'Carla_54', 'joy')
# ('anna westland', 'Carla_56', 'neutral') ('Marie Necker', 'Carla_56', 'neutral') ('Reihane Rashid', 'Carla_56', 'neutral')
# ('Rico', 'Friday_4', 'neutral') ('Lianne', 'Friday_4', 'neutral') ('Keval', 'Friday_4', 'neutral')
# ('Rico', 'Friday_6', 'joy') ('Lianne', 'Friday_6', 'neutral') ('Keval', 'Friday_6', 'neutral')
# ('Rico', 'Friday_8', 'joy') ('Lianne', 'Friday_8', 'joy') ('Keval', 'Friday_8', 'joy')
# ('Rico', 'Friday_10', 'joy') ('Lianne', 'Friday_10', 'joy') ('Keval', 'Friday_10', 'joy')
# ('Rico', 'Friday_12', 'neutral') ('Lianne', 'Friday_12', 'neutral') ('Keval', 'Friday_12', 'joy')
# ('Rico', 'Friday_14', 'joy') ('Lianne', 'Friday_14', 'anger') ('Keval', 'Friday_14', 'neutral')
# ('Rico', 'Friday_16', 'anger') ('Lianne', 'Friday_16', 'disgust') ('Keval', 'Friday_16', 'disgust')
# ('Rico', 'Friday_18', 'sadness') ('Lianne', 'Friday_18', 'sadness') ('Keval', 'Friday_18', 'sadness')
# ('Rico', 'Friday_20', 'neutral') ('Lianne', 'Friday_20', 'neutral') ('Keval', 'Friday_20', 'neutral')
# ('Rico', 'Friday_22', 'neutral') ('Lianne', 'Friday_22', 'sadness') ('Keval', 'Friday_22', 'sadness')
# ('Rico', 'Friday_24', 'neutral') ('Lianne', 'Friday_24', 'neutral') ('Keval', 'Friday_24', 'neutral')
# ('Rico', 'Friday_26', 'neutral') ('Lianne', 'Friday_26', 'anger') ('Keval', 'Friday_26', 'neutral')
# ('Rico', 'Friday_28', 'neutral') ('Lianne', 'Friday_28', 'disgust') ('Keval', 'Friday_28', 'anger')
# ('Rico', 'Friday_30', 'fear') ('Lianne', 'Friday_30', 'fear') ('Keval', 'Friday_30', 'fear')
# ('Rico', 'Friday_32', 'fear') ('Lianne', 'Friday_32', 'fear') ('Keval', 'Friday_32', 'neutral')
# ('Rico', 'Friday_34', 'fear') ('Lianne', 'Friday_34', 'fear') ('Keval', 'Friday_34', 'surprise')
# ('Rico', 'Friday_36', 'neutral') ('Lianne', 'Friday_36', 'joy') ('Keval', 'Friday_36', 'joy')
# ('Rico', 'Friday_38', 'neutral') ('Lianne', 'Friday_38', 'neutral') ('Keval', 'Friday_38', 'neutral')
# ('Rico', 'Friday_40', 'neutral') ('Lianne', 'Friday_40', 'joy') ('Keval', 'Friday_40', 'joy')
# ('Rico', 'Friday_42', 'neutral') ('Lianne', 'Friday_42', 'neutral') ('Keval', 'Friday_42', 'neutral')
# ('Rico', 'Gale_4', 'sadness') ('Piek', 'Gale_4', 'sadness') ('Keval', 'Gale_4', 'sadness')
# ('Rico', 'Gale_6', 'neutral') ('Piek', 'Gale_6', 'sadness') ('Keval', 'Gale_6', 'neutral')
# ('Rico', 'Gale_8', 'neutral') ('Piek', 'Gale_8', 'sadness') ('Keval', 'Gale_8', 'fear')
# ('Rico', 'Gale_10', 'neutral') ('Piek', 'Gale_10', 'neutral') ('Keval', 'Gale_10', 'neutral')
# ('Rico', 'Gale_12', 'neutral') ('Piek', 'Gale_12', 'neutral') ('Keval', 'Gale_12', 'neutral')
# ('Rico', 'Gale_14', 'anger') ('Piek', 'Gale_14', 'anger') ('Keval', 'Gale_14', 'disgust')
# ('Rico', 'Gale_16', 'neutral') ('Piek', 'Gale_16', 'neutral') ('Keval', 'Gale_16', 'anger')
# ('Rico', 'Gale_18', 'joy') ('Piek', 'Gale_18', 'joy') ('Keval', 'Gale_18', 'surprise')
# ('Rico', 'Gale_20', 'neutral') ('Piek', 'Gale_20', 'joy') ('Keval', 'Gale_20', 'joy')
# ('Rico', 'Gale_22', 'neutral') ('Piek', 'Gale_22', 'neutral') ('Keval', 'Gale_22', 'neutral')
# ('Rico', 'Gale_24', 'fear') ('Piek', 'Gale_24', 'fear') ('Keval', 'Gale_24', 'fear')
# ('Rico', 'Gale_26', 'neutral') ('Piek', 'Gale_26', 'neutral') ('Keval', 'Gale_26', 'surprise')
# ('Rico', 'Gale_28', 'neutral') ('Piek', 'Gale_28', 'fear') ('Keval', 'Gale_28', 'sadness')
# ('Rico', 'Gale_30', 'neutral') ('Piek', 'Gale_30', 'neutral') ('Keval', 'Gale_30', 'neutral')
# ('Rico', 'Gale_32', 'neutral') ('Piek', 'Gale_32', 'neutral') ('Keval', 'Gale_32', 'neutral')
# ('Rico', 'Gale_34', 'neutral') ('Piek', 'Gale_34', 'neutral') ('Keval', 'Gale_34', 'joy')
# ('Rico', 'Gale_36', 'neutral') ('Piek', 'Gale_36', 'neutral') ('Keval', 'Gale_36', 'neutral')
# ('Rico', 'Gale_38', 'neutral') ('Piek', 'Gale_38', 'fear') ('Keval', 'Gale_38', 'fear')
# ('Rico', 'Gale_40', 'neutral') ('Piek', 'Gale_40', 'surprise') ('Keval', 'Gale_40', 'surprise')
# ('Rico', 'Gale_42', 'fear') ('Piek', 'Gale_42', 'fear') ('Keval', 'Gale_42', 'anger')
# ('Rico', 'Gale_44', 'neutral') ('Piek', 'Gale_44', 'neutral') ('Keval', 'Gale_44', 'neutral')
# ('Rico', 'Gale_46', 'neutral') ('Piek', 'Gale_46', 'sadness') ('Keval', 'Gale_46', 'sadness')
# ('Rico', 'Gale_48', 'neutral') ('Piek', 'Gale_48', 'neutral') ('Keval', 'Gale_48', 'neutral')
# ('Rico', 'Gale_50', 'neutral') ('Piek', 'Gale_50', 'neutral') ('Keval', 'Gale_50', 'neutral')
# ('Lianne', 'Dana_4', 'joy') ('Marie Necker', 'Dana_4', 'joy') ('Reihane Rashid', 'Dana_4', 'joy')
# ('Lianne', 'Dana_6', 'sadness') ('Marie Necker', 'Dana_6', 'sadness') ('Reihane Rashid', 'Dana_6', 'sadness')
# ('Lianne', 'Dana_8', 'joy') ('Marie Necker', 'Dana_8', 'joy') ('Reihane Rashid', 'Dana_8', 'joy')
# ('Lianne', 'Dana_10', 'fear') ('Marie Necker', 'Dana_10', 'fear') ('Reihane Rashid', 'Dana_10', 'neutral')
# ('Lianne', 'Dana_12', 'anger') ('Marie Necker', 'Dana_12', 'anger') ('Reihane Rashid', 'Dana_12', 'anger')
# ('Lianne', 'Dana_14', 'sadness') ('Marie Necker', 'Dana_14', 'sadness') ('Reihane Rashid', 'Dana_14', 'sadness')
# ('Lianne', 'Dana_16', 'joy') ('Marie Necker', 'Dana_16', 'neutral') ('Reihane Rashid', 'Dana_16', 'joy')
# ('Lianne', 'Dana_18', 'sadness') ('Marie Necker', 'Dana_18', 'neutral') ('Reihane Rashid', 'Dana_18', 'neutral')
# ('Lianne', 'Dana_20', 'joy') ('Marie Necker', 'Dana_20', 'joy') ('Reihane Rashid', 'Dana_20', 'joy')
# ('Lianne', 'Dana_22', 'neutral') ('Marie Necker', 'Dana_22', 'neutral') ('Reihane Rashid', 'Dana_22', 'neutral')
# ('Trisha', 'Louise_4', 'joy') ('missing2', 'Louise_4', 'missing') ('missing3', 'Louise_4', 'missing')
# ('Trisha', 'Louise_6', 'surprise') ('missing2', 'Louise_6', 'missing') ('missing3', 'Louise_6', 'missing')
# ('Trisha', 'Louise_8', 'surprise') ('missing2', 'Louise_8', 'missing') ('missing3', 'Louise_8', 'missing')
# ('Trisha', 'Louise_10', 'anger') ('missing2', 'Louise_10', 'missing') ('missing3', 'Louise_10', 'missing')
# ('Trisha', 'Louise_12', 'anger') ('missing2', 'Louise_12', 'missing') ('missing3', 'Louise_12', 'missing')
# ('Trisha', 'Louise_14', 'sadness') ('missing2', 'Louise_14', 'missing') ('missing3', 'Louise_14', 'missing')
# ('Trisha', 'Louise_16', 'anger') ('missing2', 'Louise_16', 'missing') ('missing3', 'Louise_16', 'missing')
# ('Trisha', 'Louise_18', 'anger') ('missing2', 'Louise_18', 'missing') ('missing3', 'Louise_18', 'missing')
# ('Trisha', 'Louise_20', 'anger') ('missing2', 'Louise_20', 'missing') ('missing3', 'Louise_20', 'missing')
# ('Trisha', 'Louise_22', 'neutral') ('missing2', 'Louise_22', 'missing') ('missing3', 'Louise_22', 'missing')
# ('Trisha', 'Louise_24', 'disgust') ('missing2', 'Louise_24', 'missing') ('missing3', 'Louise_24', 'missing')
# ('Trisha', 'Louise_26', 'neutral') ('missing2', 'Louise_26', 'missing') ('missing3', 'Louise_26', 'missing')
# ('Trisha', 'Louise_28', 'anger') ('missing2', 'Louise_28', 'missing') ('missing3', 'Louise_28', 'missing')
# ('Trisha', 'Louise_30', 'neutral') ('missing2', 'Louise_30', 'missing') ('missing3', 'Louise_30', 'missing')
# ('Trisha', 'Louise_32', 'neutral') ('missing2', 'Louise_32', 'missing') ('missing3', 'Louise_32', 'missing')
# ('Trisha', 'Louise_34', 'neutral') ('missing2', 'Louise_34', 'missing') ('missing3', 'Louise_34', 'missing')
# ('Trisha', 'Louise_36', 'sadness') ('missing2', 'Louise_36', 'missing') ('missing3', 'Louise_36', 'missing')
# ('Trisha', 'Louise_38', 'anger') ('missing2', 'Louise_38', 'missing') ('missing3', 'Louise_38', 'missing')
# ('Trisha', 'Louise_40', 'joy') ('missing2', 'Louise_40', 'missing') ('missing3', 'Louise_40', 'missing')
# ('Trisha', 'Louise_42', 'neutral') ('missing2', 'Louise_42', 'missing') ('missing3', 'Louise_42', 'missing')
# ('Trisha', 'Marco_4', 'sadness') ('Rita', 'Marco_4', 'sadness') ('missing3', 'Marco_4', 'missing')
# ('Trisha', 'Marco_6', 'anger') ('Rita', 'Marco_6', 'anger') ('missing3', 'Marco_6', 'missing')
# ('Trisha', 'Marco_8', 'anger') ('Rita', 'Marco_8', 'fear') ('missing3', 'Marco_8', 'missing')
# ('Trisha', 'Marco_10', 'anger') ('Rita', 'Marco_10', 'anger') ('missing3', 'Marco_10', 'missing')
# ('Trisha', 'Marco_12', 'surprise') ('Rita', 'Marco_12', 'fear') ('missing3', 'Marco_12', 'missing')
# ('Trisha', 'Marco_14', 'anger') ('Rita', 'Marco_14', 'anger') ('missing3', 'Marco_14', 'missing')
# ('Trisha', 'Marco_16', 'neutral') ('Rita', 'Marco_16', 'sadness') ('missing3', 'Marco_16', 'missing')
# ('Trisha', 'Marco_18', 'joy') ('Rita', 'Marco_18', 'fear') ('missing3', 'Marco_18', 'missing')
# ('Trisha', 'Marco_20', 'joy') ('Rita', 'Marco_20', 'joy') ('missing3', 'Marco_20', 'missing')
# ('Trisha', 'Marco_22', 'joy') ('Rita', 'Marco_22', 'joy') ('missing3', 'Marco_22', 'missing')
# ('Trisha', 'Marco_24', 'neutral') ('Rita', 'Marco_24', 'joy') ('missing3', 'Marco_24', 'missing')
# ('Trisha', 'Marco_26', 'sadness') ('Rita', 'Marco_26', 'sadness') ('missing3', 'Marco_26', 'missing')
# ('Trisha', 'Marco_28', 'fear') ('Rita', 'Marco_28', 'fear') ('missing3', 'Marco_28', 'missing')
# ('Trisha', 'Marco_30', 'disgust') ('Rita', 'Marco_30', 'surprise') ('missing3', 'Marco_30', 'missing')
# ('Trisha', 'Marco_32', 'sadness') ('Rita', 'Marco_32', 'sadness') ('missing3', 'Marco_32', 'missing')
# ('Trisha', 'Marco_34', 'joy') ('Rita', 'Marco_34', 'neutral') ('missing3', 'Marco_34', 'missing')
# ('Trisha', 'Marco_36', 'joy') ('Rita', 'Marco_36', 'fear') ('missing3', 'Marco_36', 'missing')
# ('Trisha', 'Marco_38', 'anger') ('Rita', 'Marco_38', 'anger') ('missing3', 'Marco_38', 'missing')
# ('Trisha', 'Marco_40', 'anger') ('Rita', 'Marco_40', 'anger') ('missing3', 'Marco_40', 'missing')
# ('Trisha', 'Marco_42', 'neutral') ('Rita', 'Marco_42', 'anger') ('missing3', 'Marco_42', 'missing')
# ('Trisha', 'Maria1_4', 'fear') ('missing2', 'Maria1_4', 'missing') ('missing3', 'Maria1_4', 'missing')
# ('Trisha', 'Maria1_6', 'fear') ('missing2', 'Maria1_6', 'missing') ('missing3', 'Maria1_6', 'missing')
# ('Trisha', 'Maria1_8', 'fear') ('missing2', 'Maria1_8', 'missing') ('missing3', 'Maria1_8', 'missing')
# ('Trisha', 'Maria1_10', 'neutral') ('missing2', 'Maria1_10', 'missing') ('missing3', 'Maria1_10', 'missing')
# ('Trisha', 'Maria1_12', 'joy') ('missing2', 'Maria1_12', 'missing') ('missing3', 'Maria1_12', 'missing')
# ('Trisha', 'Maria1_14', 'neutral') ('missing2', 'Maria1_14', 'missing') ('missing3', 'Maria1_14', 'missing')
# ('Trisha', 'Maria1_16', 'surprise') ('missing2', 'Maria1_16', 'missing') ('missing3', 'Maria1_16', 'missing')
# ('Trisha', 'Maria1_18', 'disgust') ('missing2', 'Maria1_18', 'missing') ('missing3', 'Maria1_18', 'missing')
# ('Trisha', 'Maria1_20', 'joy') ('missing2', 'Maria1_20', 'missing') ('missing3', 'Maria1_20', 'missing')
# ('Trisha', 'Maria1_22', 'joy') ('missing2', 'Maria1_22', 'missing') ('missing3', 'Maria1_22', 'missing')
# ('Trisha', 'Maria1_24', 'fear') ('missing2', 'Maria1_24', 'missing') ('missing3', 'Maria1_24', 'missing')
# ('Trisha', 'Maria1_26', 'joy') ('missing2', 'Maria1_26', 'missing') ('missing3', 'Maria1_26', 'missing')
# ('Trisha', 'Maria1_28', 'disgust') ('missing2', 'Maria1_28', 'missing') ('missing3', 'Maria1_28', 'missing')
# ('Trisha', 'Maria1_30', 'joy') ('missing2', 'Maria1_30', 'missing') ('missing3', 'Maria1_30', 'missing')
# ('Trisha', 'Maria1_32', 'surprise') ('missing2', 'Maria1_32', 'missing') ('missing3', 'Maria1_32', 'missing')
# ('Trisha', 'Maria1_34', 'joy') ('missing2', 'Maria1_34', 'missing') ('missing3', 'Maria1_34', 'missing')
# ('Trisha', 'Maria1_36', 'joy') ('missing2', 'Maria1_36', 'missing') ('missing3', 'Maria1_36', 'missing')
# ('Trisha', 'Maria1_38', 'fear') ('missing2', 'Maria1_38', 'missing') ('missing3', 'Maria1_38', 'missing')
# ('Trisha', 'Maria1_40', 'joy') ('missing2', 'Maria1_40', 'missing') ('missing3', 'Maria1_40', 'missing')
# ('Elmas', 'Pink_4', 'surprise') ('Sanne', 'Pink_4', 'neutral') ('missing3', 'Pink_4', 'missing')
# ('Elmas', 'Pink_6', 'sadness') ('Sanne', 'Pink_6', 'neutral') ('missing3', 'Pink_6', 'missing')
# ('Elmas', 'Pink_8', 'joy') ('Sanne', 'Pink_8', 'joy') ('missing3', 'Pink_8', 'missing')
# ('Elmas', 'Pink_10', 'joy') ('Sanne', 'Pink_10', 'joy') ('missing3', 'Pink_10', 'missing')
# ('Elmas', 'Pink_12', 'sadness') ('Sanne', 'Pink_12', 'sadness') ('missing3', 'Pink_12', 'missing')
# ('Elmas', 'Pink_14', 'sadness') ('Sanne', 'Pink_14', 'sadness') ('missing3', 'Pink_14', 'missing')
# ('Elmas', 'Pink_16', 'sadness') ('Sanne', 'Pink_16', 'sadness') ('missing3', 'Pink_16', 'missing')
# ('Elmas', 'Pink_18', 'sadness') ('Sanne', 'Pink_18', 'sadness') ('missing3', 'Pink_18', 'missing')
# ('Elmas', 'Pink_20', 'anger') ('Sanne', 'Pink_20', 'anger') ('missing3', 'Pink_20', 'missing')
# ('Elmas', 'Pink_22', 'anger') ('Sanne', 'Pink_22', 'anger') ('missing3', 'Pink_22', 'missing')
# ('Elmas', 'Pink_24', 'anger') ('Sanne', 'Pink_24', 'anger') ('missing3', 'Pink_24', 'missing')
# ('Elmas', 'Pink_26', 'fear') ('Sanne', 'Pink_26', 'fear') ('missing3', 'Pink_26', 'missing')
# ('Elmas', 'Pink_28', 'fear') ('Sanne', 'Pink_28', 'fear') ('missing3', 'Pink_28', 'missing')
# ('Elmas', 'Pink_30', 'fear') ('Sanne', 'Pink_30', 'fear') ('missing3', 'Pink_30', 'missing')
# ('Elmas', 'Pink_32', 'surprise') ('Sanne', 'Pink_32', 'surprise') ('missing3', 'Pink_32', 'missing')
# ('Elmas', 'Pink_34', 'surprise') ('Sanne', 'Pink_34', 'surprise') ('missing3', 'Pink_34', 'missing')
# ('Elmas', 'Pink_36', 'surprise') ('Sanne', 'Pink_36', 'surprise') ('missing3', 'Pink_36', 'missing')
# ('Elmas', 'Pink_38', 'joy') ('Sanne', 'Pink_38', 'joy') ('missing3', 'Pink_38', 'missing')
# ('Elmas', 'Pink_40', 'joy') ('Sanne', 'Pink_40', 'neutral') ('missing3', 'Pink_40', 'missing')
# ('Rita', 'Maria2_4', 'neutral') ('Carla', 'Maria2_4', 'neutral') ('Hannah', 'Maria2_4', 'neutral')
# ('Rita', 'Maria2_6', 'joy') ('Carla', 'Maria2_6', 'joy') ('Hannah', 'Maria2_6', 'joy')
# ('Rita', 'Maria2_8', 'sadness') ('Carla', 'Maria2_8', 'sadness') ('Hannah', 'Maria2_8', 'sadness')
# ('Rita', 'Maria2_10', 'sadness') ('Carla', 'Maria2_10', 'sadness') ('Hannah', 'Maria2_10', 'sadness')
# ('Rita', 'Maria2_12', 'fear') ('Carla', 'Maria2_12', 'fear') ('Hannah', 'Maria2_12', 'fear')
# ('Rita', 'Maria2_14', 'sadness') ('Carla', 'Maria2_14', 'joy') ('Hannah', 'Maria2_14', 'sadness')
# ('Rita', 'Maria2_16', 'anger') ('Carla', 'Maria2_16', 'disgust') ('Hannah', 'Maria2_16', 'anger')
# ('Rita', 'Maria2_18', 'anger') ('Carla', 'Maria2_18', 'anger') ('Hannah', 'Maria2_18', 'neutral')
# ('Rita', 'Maria2_20', 'neutral') ('Carla', 'Maria2_20', 'neutral') ('Hannah', 'Maria2_20', 'anger')
# ('Rita', 'Maria2_22', 'sadness') ('Carla', 'Maria2_22', 'joy') ('Hannah', 'Maria2_22', 'neutral')
# ('Rita', 'Maria2_24', 'neutral') ('Carla', 'Maria2_24', 'neutral') ('Hannah', 'Maria2_24', 'neutral')
# ('Rita', 'Maria2_26', 'joy') ('Carla', 'Maria2_26', 'joy') ('Hannah', 'Maria2_26', 'neutral')
# ('Rita', 'Maria2_28', 'anger') ('Carla', 'Maria2_28', 'disgust') ('Hannah', 'Maria2_28', 'anger')
# ('Rita', 'Maria2_30', 'fear') ('Carla', 'Maria2_30', 'neutral') ('Hannah', 'Maria2_30', 'neutral')
# ('Rita', 'Maria2_32', 'sadness') ('Carla', 'Maria2_32', 'sadness') ('Hannah', 'Maria2_32', 'sadness')
# ('Rita', 'Maria2_34', 'joy') ('Carla', 'Maria2_34', 'joy') ('Hannah', 'Maria2_34', 'joy')
# ('Rita', 'Maria2_36', 'sadness') ('Carla', 'Maria2_36', 'sadness') ('Hannah', 'Maria2_36', 'sadness')
# ('Rita', 'Maria2_38', 'sadness') ('Carla', 'Maria2_38', 'sadness') ('Hannah', 'Maria2_38', 'sadness')
# ('Rita', 'Maria2_40', 'neutral') ('Carla', 'Maria2_40', 'neutral') ('Hannah', 'Maria2_40', 'neutral')
# ('Piek', 'Gino_4', 'neutral') ('Giulia', 'Gino_4', 'neutral') ('Keval', 'Gino_4', 'neutral')
# ('Piek', 'Gino_6', 'joy') ('Giulia', 'Gino_6', 'joy') ('Keval', 'Gino_6', 'joy')
# ('Piek', 'Gino_8', 'sadness') ('Giulia', 'Gino_8', 'sadness') ('Keval', 'Gino_8', 'sadness')
# ('Piek', 'Gino_10', 'disgust') ('Giulia', 'Gino_10', 'disgust') ('Keval', 'Gino_10', 'disgust')
# ('Piek', 'Gino_12', 'anger') ('Giulia', 'Gino_12', 'anger') ('Keval', 'Gino_12', 'anger')
# ('Piek', 'Gino_14', 'neutral') ('Giulia', 'Gino_14', 'joy') ('Keval', 'Gino_14', 'joy')
# ('Piek', 'Gino_16', 'neutral') ('Giulia', 'Gino_16', 'sadness') ('Keval', 'Gino_16', 'sadness')
# ('Piek', 'Gino_18', 'neutral') ('Giulia', 'Gino_18', 'neutral') ('Keval', 'Gino_18', 'neutral')
# ('Piek', 'Gino_20', 'surprise') ('Giulia', 'Gino_20', 'surprise') ('Keval', 'Gino_20', 'surprise')
# ('Piek', 'Gino_22', 'fear') ('Giulia', 'Gino_22', 'fear') ('Keval', 'Gino_22', 'fear')
# ('Piek', 'Gino_24', 'fear') ('Giulia', 'Gino_24', 'fear') ('Keval', 'Gino_24', 'fear')
# ('Piek', 'Gino_26', 'neutral') ('Giulia', 'Gino_26', 'neutral') ('Keval', 'Gino_26', 'disgust')
# ('Piek', 'Gino_28', 'neutral') ('Giulia', 'Gino_28', 'neutral') ('Keval', 'Gino_28', 'neutral')
# ('Keze', 'Max_2', 'neutral') ('Carla', 'Max_2', 'neutral') ('Manar', 'Max_2', 'neutral')
# ('Keze', 'Max_4', 'neutral') ('Carla', 'Max_4', 'neutral') ('Manar', 'Max_4', 'sadness')
# ('Keze', 'Max_6', 'joy') ('Carla', 'Max_6', 'joy') ('Manar', 'Max_6', 'joy')
# ('Keze', 'Max_8', 'fear') ('Carla', 'Max_8', 'sadness') ('Manar', 'Max_8', 'sadness')
# ('Keze', 'Max_10', 'neutral') ('Carla', 'Max_10', 'neutral') ('Manar', 'Max_10', 'neutral')
# ('Keze', 'Max_12', 'neutral') ('Carla', 'Max_12', 'neutral') ('Manar', 'Max_12', 'anger')
# ('Keze', 'Max_14', 'joy') ('Carla', 'Max_14', 'joy') ('Manar', 'Max_14', 'joy')
# ('Keze', 'Max_16', 'fear') ('Carla', 'Max_16', 'disgust') ('Manar', 'Max_16', 'fear')
# ('Keze', 'Max_18', 'neutral') ('Carla', 'Max_18', 'neutral') ('Manar', 'Max_18', 'neutral')
# ('Keze', 'Max_20', 'joy') ('Carla', 'Max_20', 'joy') ('Manar', 'Max_20', 'joy')
# ('Keze', 'Max_22', 'sadness') ('Carla', 'Max_22', 'sadness') ('Manar', 'Max_22', 'sadness')
# ('Keze', 'Max_24', 'sadness') ('Carla', 'Max_24', 'sadness') ('Manar', 'Max_24', 'sadness')
# ('Keze', 'Max_26', 'surprise') ('Carla', 'Max_26', 'surprise') ('Manar', 'Max_26', 'joy')
# ('Keze', 'Max_28', 'anger') ('Carla', 'Max_28', 'anger') ('Manar', 'Max_28', 'anger')
# ('Keze', 'Max_30', 'anger') ('Carla', 'Max_30', 'anger') ('Manar', 'Max_30', 'anger')
# ('Keze', 'Max_32', 'sadness') ('Carla', 'Max_32', 'sadness') ('Manar', 'Max_32', 'disgust')
# ('Keze', 'Max_34', 'neutral') ('Carla', 'Max_34', 'neutral') ('Manar', 'Max_34', 'neutral')
# ('Keze', 'Max_36', 'neutral') ('Carla', 'Max_36', 'joy') ('Manar', 'Max_36', 'joy')
# ('Keze', 'Max_38', 'neutral') ('Carla', 'Max_38', 'neutral') ('Manar', 'Max_38', 'neutral')
# ('Keze', 'Max_40', 'joy') ('Carla', 'Max_40', 'joy') ('Manar', 'Max_40', 'joy')
# ('Keze', 'Max_42', 'neutral') ('Carla', 'Max_42', 'neutral') ('Manar', 'Max_42', 'neutral')
# ('Keze', 'Max_44', 'fear') ('Carla', 'Max_44', 'fear') ('Manar', 'Max_44', 'fear')
# ('Keze', 'Max_46', 'joy') ('Carla', 'Max_46', 'surprise') ('Manar', 'Max_46', 'joy')
# ('Keze', 'Max_48', 'fear') ('Carla', 'Max_48', 'fear') ('Manar', 'Max_48', 'fear')
# ('Keze', 'Max_50', 'joy') ('Carla', 'Max_50', 'joy') ('Manar', 'Max_50', 'joy')
# ('Keze', 'Max_52', 'neutral') ('Carla', 'Max_52', 'neutral') ('Manar', 'Max_52', 'neutral')
# ('Carla', 'Martin_4', 'sadness') ('Manar', 'Martin_4', 'sadness') ('missing3', 'Martin_4', 'missing')
# ('Carla', 'Martin_6', 'sadness') ('Manar', 'Martin_6', 'fear') ('missing3', 'Martin_6', 'missing')
# ('Carla', 'Martin_8', 'fear') ('Manar', 'Martin_8', 'fear') ('missing3', 'Martin_8', 'missing')
# ('Carla', 'Martin_10', 'neutral') ('Manar', 'Martin_10', 'neutral') ('missing3', 'Martin_10', 'missing')
# ('Carla', 'Martin_12', 'sadness') ('Manar', 'Martin_12', 'fear') ('missing3', 'Martin_12', 'missing')
# ('Carla', 'Martin_14', 'disgust') ('Manar', 'Martin_14', 'neutral') ('missing3', 'Martin_14', 'missing')
# ('Carla', 'Martin_16', 'disgust') ('Manar', 'Martin_16', 'neutral') ('missing3', 'Martin_16', 'missing')
# ('Carla', 'Martin_18', 'anger') ('Manar', 'Martin_18', 'sadness') ('missing3', 'Martin_18', 'missing')
# ('Carla', 'Martin_20', 'sadness') ('Manar', 'Martin_20', 'sadness') ('missing3', 'Martin_20', 'missing')
# ('Carla', 'Martin_22', 'sadness') ('Manar', 'Martin_22', 'sadness') ('missing3', 'Martin_22', 'missing')
# ('Carla', 'Martin_24', 'neutral') ('Manar', 'Martin_24', 'neutral') ('missing3', 'Martin_24', 'missing')
# ('Carla', 'Martin_26', 'joy') ('Manar', 'Martin_26', 'joy') ('missing3', 'Martin_26', 'missing')
# ('Carla', 'Martin_28', 'neutral') ('Manar', 'Martin_28', 'joy') ('missing3', 'Martin_28', 'missing')
# ('Carla', 'Martin_30', 'surprise') ('Manar', 'Martin_30', 'joy') ('missing3', 'Martin_30', 'missing')
# ('Carla', 'Martin_32', 'joy') ('Manar', 'Martin_32', 'joy') ('missing3', 'Martin_32', 'missing')
# ('Carla', 'Martin_34', 'fear') ('Manar', 'Martin_34', 'disgust') ('missing3', 'Martin_34', 'missing')
# ('Carla', 'Martin_36', 'neutral') ('Manar', 'Martin_36', 'joy') ('missing3', 'Martin_36', 'missing')
# ('Carla', 'Martin_38', 'fear') ('Manar', 'Martin_38', 'joy') ('missing3', 'Martin_38', 'missing')
# ('Carla', 'Martin_40', 'neutral') ('Manar', 'Martin_40', 'joy') ('missing3', 'Martin_40', 'missing')
# ('Carla', 'Martin_42', 'neutral') ('Manar', 'Martin_42', 'anger') ('missing3', 'Martin_42', 'missing')
# ('Hannah', 'Paul_4', 'joy') ('Masoumeh_Javadi_Zarnaghi', 'Paul_4', 'surprise') ('Sanne', 'Paul_4', 'surprise')
# ('Hannah', 'Paul_6', 'neutral') ('Masoumeh_Javadi_Zarnaghi', 'Paul_6', 'surprise') ('Sanne', 'Paul_6', 'neutral')
# ('Hannah', 'Paul_8', 'anger') ('Masoumeh_Javadi_Zarnaghi', 'Paul_8', 'anger') ('Sanne', 'Paul_8', 'anger')
# ('Hannah', 'Paul_10', 'anger') ('Masoumeh_Javadi_Zarnaghi', 'Paul_10', 'fear') ('Sanne', 'Paul_10', 'anger')
# ('Hannah', 'Paul_12', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Paul_12', 'fear') ('Sanne', 'Paul_12', 'fear')
# ('Hannah', 'Paul_14', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Paul_14', 'fear') ('Sanne', 'Paul_14', 'fear')
# ('Hannah', 'Paul_16', 'surprise') ('Masoumeh_Javadi_Zarnaghi', 'Paul_16', 'neutral') ('Sanne', 'Paul_16', 'fear')
# ('Hannah', 'Paul_2', 'fear') ('Masoumeh_Javadi_Zarnaghi', 'Paul_2', 'neutral') ('Sanne', 'Paul_2', 'fear')
