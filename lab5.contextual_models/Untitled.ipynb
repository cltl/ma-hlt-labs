# %% [markdown]
# # Lab5.1 Introduction to contextual models

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-1.12.1-py3-none-any.whl (270 kB)
#      |████████████████████████████████| 270 kB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from datasets) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from datasets) (2.25.0)
# Collecting huggingface-hub<0.1.0,>=0.0.14
#   Downloading huggingface_hub-0.0.17-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 4.7 MB/s eta 0:00:01
# Collecting tqdm>=4.62.1
#   Using cached tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
# Requirement already satisfied: pandas in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from datasets) (1.3.0)
# Collecting xxhash
#   Using cached xxhash-2.0.2-cp37-cp37m-macosx_10_9_x86_64.whl (31 kB)
# Requirement already satisfied: packaging in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from datasets) (20.1)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-macosx_10_14_x86_64.whl (644 kB)
#      |████████████████████████████████| 644 kB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from datasets) (1.20.0)
# Collecting multiprocess
#   Using cached multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
# Requirement already satisfied: importlib-metadata in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from datasets) (2.0.0)
# Collecting dill
#   Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting fsspec[http]>=2021.05.0
#   Using cached fsspec-2021.8.1-py3-none-any.whl (119 kB)
# Requirement already satisfied: filelock in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from huggingface-hub<0.1.0,>=0.0.14->datasets) (3.0.12)
# Requirement already satisfied: typing-extensions in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from huggingface-hub<0.1.0,>=0.0.14->datasets) (3.7.4.3)
# Collecting packaging
#   Using cached packaging-21.0-py3-none-any.whl (40 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2020.11.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-macosx_10_14_x86_64.whl (123 kB)
#      |████████████████████████████████| 123 kB 8.6 MB/s eta 0:00:01
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-macosx_10_14_x86_64.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.1 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from aiohttp->datasets) (19.3.0)
# Requirement already satisfied: zipp>=0.5 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->datasets) (3.4.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from pandas->datasets) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/piek/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, yarl, async-timeout, tqdm, packaging, fsspec, dill, aiohttp, xxhash, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.52.0
#     Uninstalling tqdm-4.52.0:
#       Successfully uninstalled tqdm-4.52.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.1
#     Uninstalling packaging-20.1:
#       Successfully uninstalled packaging-20.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.6.2
#     Uninstalling fsspec-0.6.2:
#       Successfully uninstalled fsspec-0.6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 datasets-1.12.1 dill-0.3.4 fsspec-2021.8.1 huggingface-hub-0.0.17 multidict-5.1.0 multiprocess-0.70.12.2 packaging-21.0 tqdm-4.62.2 xxhash-2.0.2 yarl-1.6.3
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/piek/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import datasets

all_ds = datasets.list_datasets()
print(len(all_ds))
# Out:
# 1415

# %%
all_ds[:10]
# Out:
# ['acronym_identification',
#  'ade_corpus_v2',
#  'adversarial_qa',
#  'aeslc',
#  'afrikaans_ner_corpus',
#  'ag_news',
#  'ai2_arc',
#  'air_dialogue',
#  'ajgt_twitter_ar',
#  'allegro_reviews']

# %% [markdown]
# We can download the OSCAR Italian corpus using HF’s datasets. However, we should be careful as the full dataset contains 11.3B samples. A total of ~69GB of data. HF allows us to specify that we’d like only a portion of the full dataset using the split parameter.

# %%
dataset = datasets.load_dataset(
    'oscar',
    'unshuffled_deduplicated_it',
    split='train[:1000000]')
# Out:
# Downloading:   0%|          | 0.00/5.58k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/359k [00:00<?, ?B/s]
# Downloading and preparing dataset oscar/unshuffled_deduplicated_it (download: 26.01 GiB, generated: 68.77 GiB, post-processed: Unknown size, total: 94.79 GiB) to /Users/piek/.cache/huggingface/datasets/oscar/unshuffled_deduplicated_it/1.0.0/84838bd49d2295f62008383b05620571535451d84545037bb94d6f3501651df2...
# Downloading:   0%|          | 0.00/3.23k [00:00<?, ?B/s]
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-14:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in _single_map_nested
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 161, in <listcomp>
#     mapped = [_single_map_nested((function, v, types, None, True)) for v in pbar]
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py", line 143, in _single_map_nested
#     return function(data_struct)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py", line 217, in _download
#     return cached_path(url_or_filename, download_config=download_config)
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 299, in cached_path
#     use_auth_token=download_config.use_auth_token,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 653, in get_from_cache
#     max_retries=max_retries,
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 454, in http_get
#     for chunk in response.iter_content(chunk_size=1024):
#   File "/Users/piek/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/file_utils.py", line 454, in http_get
#     for chunk in response.iter_content(chunk_size=1024):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a243e7da3b36> in <module>
#       2     'oscar',
#       3     'unshuffled_deduplicated_it',
# ----> 4     split='train[:1000000]')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, script_version, use_auth_token, task, streaming, **config_kwargs)
#    1115         ignore_verifications=ignore_verifications,
#    1116         try_from_hf_gcs=try_from_hf_gcs,
# -> 1117         use_auth_token=use_auth_token,
#    1118     )
#    1119
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datasets/builder.py in download_and_prepare(self, download_config, download_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, **download_and_prepare_kwargs)
#     635                     if not downloaded_from_gcs:
#     636                         self._download_and_prepare(
# --> 637                             dl_manager=dl_manager, verify_infos=verify_infos, **download_and_prepare_kwargs
#     638                         )
#     639                     # Sync info
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datasets/builder.py in _download_and_prepare(self, dl_manager, verify_infos, **prepare_split_kwargs)
#     702         split_dict = SplitDict(dataset_name=self.name)
#     703         split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# --> 704         split_generators = self._split_generators(dl_manager, **split_generators_kwargs)
#     705
#     706         # Checksums verification
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/oscar/84838bd49d2295f62008383b05620571535451d84545037bb94d6f3501651df2/oscar.py in _split_generators(self, dl_manager)
#     345             data_filenames = [line.split("\t")[0] for line in f if line]
#     346             data_urls = [self.config.base_data_url + data_filename for data_filename in data_filenames]
# --> 347         downloaded_files = dl_manager.download(data_urls)
#     348         return [
#     349             datasets.SplitGenerator(name=datasets.Split.TRAIN, gen_kwargs={"filepaths": downloaded_files}),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/download_manager.py in download(self, url_or_urls)
#     195         start_time = datetime.now()
#     196         downloaded_path_or_paths = map_nested(
# --> 197             download_func, url_or_urls, map_tuple=True, num_proc=download_config.num_proc, disable_tqdm=False
#     198         )
#     199         duration = datetime.now() - start_time
#
# ~/opt/anaconda3/lib/python3.7/site-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, types, disable_tqdm)
#     231             initargs, initializer = (RLock(),), tqdm.set_lock
#     232         with Pool(num_proc, initargs=initargs, initializer=initializer) as pool:
# --> 233             mapped = pool.map(_single_map_nested, split_kwds)
#     234         logger.info("Finished {} processes".format(num_proc))
#     235         mapped = [obj for proc_res in mapped for obj in proc_res]
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# Inside our split parameter we have specified that we would like the first 2000000 samples from the train dataset (most datasets are organized into train, validation, and test sets). Although this will still download the full train set — which will be cached locally for future use.
# We can avoid downloading and caching the full dataset by adding the streaming=True parameter to load_dataset — in this case split must be set to "train" (without the [:2000000]).
