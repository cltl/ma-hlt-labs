# %% [markdown]
# ## Aggregating annotations

# %%
def check_annotations(d):
    error = []
    conversations = d["conversations"]
    for annotations in conversations:
        for annotation in annotations:
            if not 'speaker' in annotation:
                error.append('speaker')
            if not 'Annotator' in annotation:
                error.append('Annotator')
            if not 'Gold' in annotation:
                error.append('Gold')
    return error

# %% [markdown]
# #### From zip files

# %%
# import json
# import glob
# import zipfile
# import pandas as pd

# annotation_folder = "/Users/piek/Desktop/t-MA-HLT-introduction-2025/lab-assignments-2025/lab1b_annotation_submissions"
# files = glob.glob(annotation_folder + '/*.zip')
# print('Nr of files', len(files))

# all_annotations = []
# for file in files:
#     with zipfile.ZipFile(file) as myzip:
#         for filename in myzip.namelist():
#             if filename.endswith('.zip'):
#                 f = myzip.open(filename)
#                 try:
#                     d = json.load(f)
#                     error = check_annotations(d)
#                     if  error:
#                         print('Wrong data in', filename)
#                     elif not len(d)==3:
#                         print('Wrong data in', filename, len(d))
#                     else:
#                         all_annotations.extend(d)
#                 except:
#                     print('Error reading', file, filename)
# Out:
# Nr of files 28

# %%
import json
import glob
import zipfile
import pandas as pd
import os

annotation_folder = "/Users/piek/Desktop/t-MA-HLT-introduction-2025/lab-assignments-2025/lab1b_annotation_submissions"
#annotation_folder = "/Users/piek/Desktop/t-MA-HLT-introduction-2025/lab-assignments-2025/test"
files = glob.glob(annotation_folder + '/*.json')
print('Nr of files', len(files))
#print(files)
all_annotations = []
source_anno_id = {}
for filename in files:
    with open(filename) as f:
       # print(f)
            d = json.load(f)
            annos = 0
            if "persona" in d and "conversations" in d:
                all_annotations.extend(d["conversations"])
                annos = len(d["conversations"])
            else:
                #old format
                all_annotations.extend(d)
                annos = len(d)
            range_annos = range(len(all_annotations))
            range_new = len(range_annos)-annos
            print(range_new)
            source_anno_id[os.path.basename(filename)]=range_annos[range_new:]
print(source_anno_id)
# Out:
# Nr of files 30
# 0
# 2
# 5
# 8
# 11
# 14
# 15
# 18
# 19
# 21
# 24
# 25
# 28
# 29
# 30
# 33
# 35
# 38
# 41
# 42
# 43
# 44
# 45
# 48
# 51
# 52
# 55
# 58
# 59
# 62
# {'nicolaasr_278323_9515236_annotator_Rico_Jason.json': range(0, 2), 'annotator_Marit_Ms. Potts.json': range(2, 5), 'massaggiag_310074_9515449_annotator_Giulia_Jackson.json': range(5, 8), 'annotator_Popa_Star..json': range(8, 11), 'annotator_Ella_Joe.json': range(11, 14), 'kashanib_306429_9523850_annotator_Bardia_Jackson.json': range(14, 15), 'langebergv_315491_9511676_annotator_Vera Langeberg_ada1.json': range(15, 18), 'westlandaw_311024_9514569_annotator_anna westland_conversations.json': range(18, 19), 'nicolaasr_278323_9515235_annotator_Rico_Dean.json': range(19, 21), 'annotator_Lianne_Dana.json': range(21, 24), 'annotator_Trisha_Louise.json': range(24, 25), 'kate_245802_9521194_annotator_Elmas_combined.json': range(25, 28), 'annotator_Rita_conversations.json': range(28, 29), 'piek_annotations_gale.json': range(29, 30), 'annotator_Keze_Conversations.json': range(30, 33), 'annotator_Ella_Bill.json': range(33, 35), 'annotator_Marie Necker_Brenda.json': range(35, 38), 'massaggiag_310074_9515450_annotator_Giulia_Jake.json': range(38, 41), 'annotator_Carla_Maria2.json': range(41, 42), 'rostanzom_314593_9524911_zia_annotations.json': range(42, 43), 'altgaßenhly_300409_9518029_hannah_ altgassen_annotations.json': range(43, 44), 'annotator_Masoumeh_Javadi_Zarnaghi_Nymera.json': range(44, 45), 'annotator_Thomas _Jake.json': range(45, 48), 'annotator_Sanne_Oek.json': range(48, 51), 'annotator_Manar_Martin.json': range(51, 52), 'massaggiag_310074_9515448_annotator_Giulia_Gino.json': range(52, 55), 'annotator_Keval_Friday.json': range(55, 58), 'rashidr_292185_9523400_annotator_Reihane Rashid_Carla.json': range(58, 59), 'stergiopouloumf_306458_9524840_Lina .json': range(59, 62), 'annotator_Gianmarco_Woland.json': range(62, 65)}

# %%
print('Total number of annotations', len(all_annotations))
# Out:
# Total number of annotations 65

# %% [markdown]
# Create an annotation dictionary for all turns that are not by the AI or Human but another speaker.

# %%
def extend_anno_dict(anno_dict, annotator_dict, annotation, index):
    try:
        if 'Annotator' in annotation and 'Gold' in annotation:
            speaker = annotation['speaker']
            annotator = annotation['Annotator']
            emotion = annotation['Gold']
            if not speaker == 'AI' and not speaker == 'Human' and not annotator=='auto':
                turn_id = annotation['turn_id']
                key = speaker+str(turn_id)
                if annotator in annotator_dict:
                    if key in annotator_dict[annotator]:
                        print('Duplicate', key, annotator)
                        return
                    else:
                        annotator_dict[annotator].append(key)
                else:
                    annotator_dict[annotator]= [key]
                if key in anno_dict:
                    anno = anno_dict[key]
                    if 'Votes' in anno:
                        anno['Votes'].append(emotion)
                        anno['Annotators'].append(annotator)
                    else:
                        anno['Votes'] = [emotion]
                        anno['Annotators']= [annotator]
                else:
                    annotation['Votes'] = [emotion]
                    annotation['Annotators']= [annotator]
                    anno_dict[key]=annotation
        else:
            speaker = annotation['speaker']
#            if not speaker == 'AI' and not speaker == 'Human': 
#                print('Skipping this annotation', index)
               # print(annotation)
    except Exception as e:
        print(f"Error: {str(e)}")
        print('Error in annotation', index)
            
anno_dict = {}
annotator_dict = {}
for index, annotations in enumerate(all_annotations):
    for annotation in annotations:
        if type(annotation)==list:
            #### old format!
            for anno in annotation:
                extend_anno_dict(anno_dict, annotator_dict, anno, index)
        else:
            extend_anno_dict(anno_dict, annotator_dict, annotation, index)
# Out:
# Duplicate Bill4 Rico
# Duplicate Bill2 Rico
# Duplicate Bill4 Rico
# Duplicate Bill2 Rico
# Duplicate Ada14 Popa
# Duplicate Ada16 Popa
# Duplicate Ada18 Popa
# Duplicate Ada110 Popa
# Duplicate Ada112 Popa
# Duplicate Ada114 Popa
# Duplicate Ada116 Popa
# Duplicate Bill4 Ella
# Duplicate Bill2 Ella
# %%
print(len(anno_dict))
dict_file = "all_annotations_dict.json"
with open(dict_file,'w') as file:
    json.dump(anno_dict, file, indent = 4)

print(len(annotator_dict))

dict_file = "annotator_dict.json"
with open(dict_file,'w') as file:
    json.dump(annotator_dict, file, indent = 4)
# Out:
# 604
# 25

# %%
merged_annotations = []
for key in anno_dict:
    merged_annotations.append(anno_dict[key])
all_file = "all_annotations.json"
with open(all_file,'w') as file:
    json.dump(merged_annotations, file, indent = 4)

# %% [markdown]
# ## Data statistics

# %%
from collections import Counter, OrderedDict
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_labels_with_counts(labels, values):
    total = 0
    for v in values:
        total+=v
    print('Total of values', total)
    ax = sns.barplot(x=labels, y=values)
    #rotate x-axis labels
    ax.set_xticklabels(ax.get_xticklabels(), rotation=65)
    # Add values above bars
    for i, v in enumerate(values):
        ax.text(i, v + 0.2, str(int((v/total*100)))+'%', ha='center')
    plt.show()

# %%
df = pd.read_json("all_annotations.json")
df.head()
# Out:
#                                            utterance speaker  turn_id  \
# 0  Can you give me ideas on how to deal with some...    Bill        4
# 1  I am so angry. I am blind with rage. I want to...    Bill        6
# 2  But at the same time I am happy that it is ove...    Bill        8
# 3  When I found out I was so surprised. I saw no ...    Bill       10
# 4      Please do give me some steps to get over this    Bill       12
#
#        Gold Annotator                                              Votes  \
# 0   neutral      Rico  [neutral, neutral, sadness, sadness, neutral, ...
# 1     anger      Rico         [anger, anger, anger, anger, anger, anger]
# 2       joy      Rico                 [joy, joy, anger, anger, joy, joy]
# 3  surprise      Rico  [surprise, surprise, surprise, surprise, surpr...
# 4   neutral      Rico  [neutral, neutral, neutral, neutral, neutral, ...
#
#                                           Annotators
# 0  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...
# 1  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...
# 2  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...
# 3  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...
# 4  [Rico, Ella, Vera Langeberg, Giulia, zia, Thom...

# %%
speakers = df['speaker']
print('Speaker values', set(speakers))
print()
counts = Counter(speakers)
counts_sorted = OrderedDict(sorted(counts.items()))
print(counts_sorted)
labels = list(counts_sorted.keys())
values = list(counts_sorted.values())
plot_labels_with_counts(labels, values)
# Out:
# Speaker values {'Nymera Vaelith', 'Maria2', 'Pink', 'Ada1', 'Marco', 'Jason', 'Dana', 'Dean', 'Max', 'Jackson', 'Maria1', 'Bizmuth', 'Brenda', 'Ms. Potts', 'Friday', 'Star.', 'Joe', 'Gino', 'Louise', 'Paul', 'Oek', 'Gale', 'Lennart', 'Woland', 'Bill', 'Jake', 'Carla', 'Martin', 'Ada2'}
#
# OrderedDict([('Ada1', 20), ('Ada2', 19), ('Bill', 16), ('Bizmuth', 19), ('Brenda', 24), ('Carla', 27), ('Dana', 10), ('Dean', 25), ('Friday', 20), ('Gale', 24), ('Gino', 13), ('Jackson', 29), ('Jake', 21), ('Jason', 15), ('Joe', 23), ('Lennart', 42), ('Louise', 20), ('Marco', 20), ('Maria1', 19), ('Maria2', 19), ('Martin', 20), ('Max', 26), ('Ms. Potts', 21), ('Nymera Vaelith', 20), ('Oek', 20), ('Paul', 8), ('Pink', 19), ('Star.', 25), ('Woland', 20)])
# Total of values 604
# /var/folders/6w/bw7dqbl9727c48pcjjh32r140000gn/T/ipykernel_96773/2446219359.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=65)

# %%
talks = {}
emotions = []
for ind in df.index:
    votes = df['Votes'][ind]
    counts = Counter(votes)
    counts_sorted = OrderedDict(sorted(counts.items()))
    #print(counts_sorted)
    emotion = next(iter(counts_sorted))
    annotator = df['Annotator'][ind]
    speaker = df['speaker'][ind]
    if not annotator=='auto' and not str(emotion)=='nan':
        emotions.append(emotion)
    if speaker in talks:
        talks[speaker].append(str(annotator)+"-"+str(emotion))
    else:
        talks[speaker]=[str(annotator)+"-"+str(emotion)]

print('Emotion values', set(emotions))
print()
counts = Counter(emotions)
counts_sorted = OrderedDict(sorted(counts.items()))
print(counts_sorted)
labels = list(counts_sorted.keys())
values = list(counts_sorted.values())
plot_labels_with_counts(labels, values)
# Out:
# Emotion values {'fear', 'joy', 'disgust', 'anger', 'surprise', 'sadness', 'neutral'}
#
# OrderedDict([('anger', 131), ('disgust', 14), ('fear', 101), ('joy', 129), ('neutral', 171), ('sadness', 47), ('surprise', 11)])
# Total of values 604
# /var/folders/6w/bw7dqbl9727c48pcjjh32r140000gn/T/ipykernel_96773/2446219359.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=65)

# %% [markdown]
# ## Adjudication

# %%
talks = {}
emotions = []
for ind in df.index:
    votes = df['Votes'][ind]
    counts = Counter(votes)
    emotion = ""
    count = 0
    for e in counts:
        if counts[e]>count:
            emotion = e
            count = counts[e]
        elif counts[e]==count and emotion=="neutral":
            emotion = e
            count = counts[e]
    #print(emotion, counts)
    annotator = df['Annotator'][ind]
    speaker = df['speaker'][ind]
    if not annotator=='auto' and not str(emotion)=='nan':
        emotions.append(emotion)
    if speaker in talks:
        talks[speaker].append(str(annotator)+"-"+str(emotion))
    else:
        talks[speaker]=[str(annotator)+"-"+str(emotion)]
df['Adjudication']=emotions
adjudicated_file = "adjudicated_annotations.json"
df.to_json(adjudicated_file, orient="records", indent = 4)
    
print('Emotion values', set(emotions))
print()
counts = Counter(emotions)
counts_sorted = OrderedDict(sorted(counts.items()))
print(counts_sorted)
labels = list(counts_sorted.keys())
values = list(counts_sorted.values())
plot_labels_with_counts(labels, values)
# Out:
# Emotion values {'fear', 'joy', 'disgust', 'anger', 'surprise', 'sadness', 'neutral'}
#
# OrderedDict([('anger', 95), ('disgust', 11), ('fear', 77), ('joy', 111), ('neutral', 204), ('sadness', 76), ('surprise', 30)])
# Total of values 604
# /var/folders/6w/bw7dqbl9727c48pcjjh32r140000gn/T/ipykernel_96773/2446219359.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=65)

# %% [markdown]
# ## End of notebook
